# %% [markdown]
# # OpenStreetMap Data Case Study
# ## by Sergio Marfull
# __________________________________________

# %% [markdown]
# ## Map Area

# %% [markdown]
# Madrid, Spain

# %% [markdown]
# * https://www.openstreetmap.org/relation/5326784

# %% [markdown]
# I was born in Madrid and I decided to investigate the dataset of my city and, who knows, I may help the OpenStreetMap community someday to get an improved database!

# %% [markdown]
# ## Setup and preparing the dataset

# %%
## import all the necessary packages to run the code

import sqlite3 as sqlite
import xml.etree.cElementTree as ET
from pprint import pprint
import re
from collections import defaultdict
from time import time
import mapparser
import tags
import users
import audit 
import schema
import data
import cerberus
import csv
import codecs

# %% [markdown]
# Open the dataset and store it in order to manipulate it in python

# %%
## store the dataset from the .osm file into a python variable
osm_file = open("OSM Madrid - XML/madrid_spain.osm","rb")

# %% [markdown]
# Create a smaller sample that can be inspected faster before investigating the entire dataset

# %%
## create a sample file, 1000 times smaller than the original file in order to speed up the 
## investigation of the dataset and the iterations of the code
sample_file = "OSM Madrid - XML/sample.osm"
t0=time()
k = 1000 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(sample_file, 'w') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(osm_file)):
        if i % k == 0:
            output.write(ET.tostring(element).decode('UTF-8'))

    output.write('</osm>')
print(time()-t0)
# Out:
# 63.55955743789673

# %% [markdown]
# ## Problems found in the Map
# ________________________________________________-

# %% [markdown]
# I have encountered so many challenges for this project. First of all, it is the first project of a kind in my life and I have gone through all existing problems of types, formats and coding. Regarding dataset problems, I encountered many syntactical problems which a fixed with the same function (audit.py), namely:
#
# * **Abbreviated street names** (Avenida, Avda., AV.,...)
# * **Misspelling** (Carretetera, punctuation,...)
# * **Incongruent versions of the same street names, mixing lower and uppercases** (Calle, calle, CALLE)
#
# I have also had one special problem: the language. In Spain, we call the street type at the beginning, and all the references that I found explained the English-speaking case (even when I asked directly in some forums). So I had to practice with the regular expression by myself until I got with the formula:

# %%
street_type_re = re.compile(r'^\w+\.?', re.IGNORECASE)

# %% [markdown]
# Since that moment, I could accelerate the project path again and correct the words replacing them for their mapping in audit.py

# %%
def audit(filename):
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(filename, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    return street_types

# %% [markdown]
# > All helper functions used in the code can be found included within the .zip file of the project

# %% [markdown]
# ## Mapparser.py

# %%
mapparser.count_tags(osm_file)

# %% [markdown]
# ## tags.py

# %%
tags.process_map(osm_file)

# %% [markdown]
# ## users.py

# %%
users.process_map(sample_file)
# Out:
# {'1011130',
#  '101150',
#  '101355',
#  '1014878',
#  '1068293',
#  '107257',
#  '1078372',
#  '110263',
#  '1168897',
#  '117664',
#  '1181326',
#  '121415',
#  '1214953',
#  '1215580',
#  '1222737',
#  '123364',
#  '1241009',
#  '1280319',
#  '13091',
#  '13135',
#  '1326584',
#  '1334676',
#  '13832',
#  '13957',
#  '1432104',
#  '1438481',
#  '1440585',
#  '1461937',
#  '1465214',
#  '1476663',
#  '14794',
#  '149606',
#  '1504312',
#  '15188',
#  '1522593',
#  '153530',
#  '153567',
#  '1569519',
#  '1580969',
#  '159810',
#  '1635134',
#  '1639933',
#  '165869',
#  '170106',
#  '1722789',
#  '1725553',
#  '1727619',
#  '173225',
#  '1735748',
#  '1754095',
#  '175769',
#  '1761936',
#  '1767321',
#  '1773299',
#  '1781370',
#  '178711',
#  '179025',
#  '1792089',
#  '179540',
#  '1796109',
#  '18004',
#  '1803492',
#  '1815833',
#  '1829683',
#  '1833457',
#  '18675',
#  '1868925',
#  '1872708',
#  '1877329',
#  '1888813',
#  '1890655',
#  '1902358',
#  '193123',
#  '1947048',
#  '1949691',
#  '1957205',
#  '1957538',
#  '196617',
#  '1974064',
#  '1977383',
#  '1995961',
#  '2018195',
#  '2019603',
#  '2024941',
#  '2047207',
#  '2049744',
#  '20587',
#  '2066928',
#  '2093808',
#  '2097018',
#  '2107780',
#  '21080',
#  '2109130',
#  '211000',
#  '2111065',
#  '2132426',
#  '2153421',
#  '2163609',
#  '217070',
#  '219376',
#  '2201799',
#  '2203560',
#  '220932',
#  '2211171',
#  '2214460',
#  '2219985',
#  '2226712',
#  '223893',
#  '2240612',
#  '2245342',
#  '2246237',
#  '224687',
#  '2257299',
#  '2258869',
#  '226626',
#  '2267575',
#  '2268702',
#  '2275526',
#  '2277975',
#  '228684',
#  '2289381',
#  '229489',
#  '2295186',
#  '2318',
#  '2339356',
#  '234702',
#  '2382920',
#  '2384856',
#  '2391600',
#  '24070',
#  '2418972',
#  '2461407',
#  '2468852',
#  '2481418',
#  '248386',
#  '2498511',
#  '2500',
#  '2508151',
#  '251029',
#  '2512300',
#  '2530281',
#  '257555',
#  '2587110',
#  '259062',
#  '2593972',
#  '2595604',
#  '2598444',
#  '2606425',
#  '26599',
#  '267081',
#  '2706893',
#  '27441',
#  '2748485',
#  '275212',
#  '2785920',
#  '28201',
#  '2827669',
#  '2835790',
#  '2841258',
#  '2855667',
#  '28803',
#  '290271',
#  '2903983',
#  '2904',
#  '2909390',
#  '2914970',
#  '292665',
#  '293845',
#  '294608',
#  '2946617',
#  '2968408',
#  '300459',
#  '3042095',
#  '3055322',
#  '3103168',
#  '3124724',
#  '313170',
#  '314231',
#  '3148901',
#  '315015',
#  '31545',
#  '316694',
#  '31826',
#  '3185706',
#  '3188422',
#  '3196761',
#  '320437',
#  '3206597',
#  '3213096',
#  '322178',
#  '3225472',
#  '322785',
#  '3251493',
#  '32529',
#  '3257136',
#  '326703',
#  '327568',
#  '329453',
#  '330336',
#  '3305489',
#  '33103',
#  '333621',
#  '3371465',
#  '339581',
#  '340025',
#  '3411754',
#  '3415461',
#  '3417876',
#  '3429234',
#  '344561',
#  '346267',
#  '347262',
#  '3489961',
#  '3502717',
#  '3507193',
#  '352000',
#  '352384',
#  '352754',
#  '3541213',
#  '355408',
#  '3561701',
#  '3584',
#  '358652',
#  '360250',
#  '3638158',
#  '3649461',
#  '366900',
#  '3676505',
#  '370404',
#  '370728',
#  '373328',
#  '378312',
#  '3801505',
#  '381188',
#  '3814573',
#  '3828090',
#  '382962',
#  '3829760',
#  '3830020',
#  '384772',
#  '3898917',
#  '396743',
#  '40397',
#  '406404',
#  '407064',
#  '41263',
#  '418825',
#  '420490',
#  '42055',
#  '42123',
#  '422066',
#  '42429',
#  '427753',
#  '4347382',
#  '435046',
#  '436572',
#  '4367141',
#  '4369761',
#  '438250',
#  '439526',
#  '44090',
#  '44160',
#  '4443896',
#  '445671',
#  '45453',
#  '4547187',
#  '45952',
#  '461005',
#  '462088',
#  '4623',
#  '464767',
#  '4647806',
#  '468314',
#  '472193',
#  '474183',
#  '4753886',
#  '475943',
#  '4796262',
#  '4866290',
#  '4871175',
#  '4887111',
#  '491515',
#  '4918711',
#  '493192',
#  '497524',
#  '497807',
#  '4997431',
#  '5032262',
#  '506780',
#  '5148505',
#  '51496',
#  '5151',
#  '5182089',
#  '519501',
#  '5202428',
#  '5258992',
#  '5265',
#  '526776',
#  '528502',
#  '532668',
#  '535109',
#  '535134',
#  '535609',
#  '5379200',
#  '53891',
#  '5392152',
#  '545193',
#  '545386',
#  '5530',
#  '5573892',
#  '557822',
#  '563346',
#  '567846',
#  '568647',
#  '582824',
#  '58410',
#  '586961',
#  '587703',
#  '587812',
#  '597019',
#  '601028',
#  '6057780',
#  '6146037',
#  '622785',
#  '62423',
#  '625415',
#  '627027',
#  '62882',
#  '630257',
#  '6302660',
#  '637801',
#  '6389',
#  '644329',
#  '648006',
#  '651622',
#  '6524272',
#  '6593080',
#  '662113',
#  '6667827',
#  '667805',
#  '67439',
#  '6757296',
#  '684143',
#  '6859928',
#  '686899',
#  '6888988',
#  '690682',
#  '695960',
#  '6959806',
#  '69765',
#  '699830',
#  '7003',
#  '7078793',
#  '708476',
#  '709828',
#  '7124894',
#  '7128153',
#  '7131643',
#  '7133376',
#  '7142389',
#  '7142553',
#  '7142889',
#  '71626',
#  '7164379',
#  '718437',
#  '7190892',
#  '7215820',
#  '7219043',
#  '7244370',
#  '7328364',
#  '735621',
#  '73791',
#  '74983',
#  '766599',
#  '777223',
#  '801220',
#  '8076',
#  '811230',
#  '82586',
#  '84486',
#  '849016',
#  '860575',
#  '86401',
#  '86541',
#  '87939',
#  '87977',
#  '880630',
#  '89290',
#  '91490',
#  '915419',
#  '926633',
#  '971',
#  '979693',
#  '98530'}

# %% [markdown]
# ## audit.py

# %%
osm_file.seek(0)
audit.test(osm_file)
# Out:
# {'11': {'11 Posterior'},
#  'A': {'A-4 KM 23.3', 'A-5'},
#  'AUTOP.': {'AUTOP. VALENCIA KM 7.1'},
#  'AUTOPISTA': {'AUTOPISTA AUTOPISTA AP-41 KM 31.780',
#                'AUTOPISTA AUTOPISTA AP41 KM 31.760'},
#  'AUTOVIA': {'AUTOVIA A-1 KM 29.1',
#              'AUTOVIA A-3 KM 62.5',
#              'AUTOVIA A-3 KM 71.9',
#              'AUTOVIA A-42 KM 57.700',
#              'AUTOVIA E-901/A-3 KM 35.2',
#              'AUTOVIA NACIONAL I KM 26.200'},
#  'AV': {'AV del Deporte', 'AV DE MOSTOLES, Nº 6'},
#  'AV.': {'AV. CASTILLA'},
#  'AVDA': {'AVDA ARCAS DE AGUA SN',
#           'AVDA DE MADRID',
#           'AVDA DEL VALLE 36 (CRTA M 604 KM 24.100)'},
#  'AVDA.': {'AVDA. ALTO DEL LEÓN, Nº 3',
#            'AVDA. DEL ANTIGÜO FERROCARRIL, Nº 1',
#            'AVDA. GENERALISIMO,12',
#            'AVDA. SAN PABLO'},
#  'AVENIDA': {'AVENIDA ANDALUCIA',
#              'AVENIDA AURELIO ALVAREZ, S/N',
#              'AVENIDA AVDA DEL SOL ESQ.AVDA DE FRANCIA, SN',
#              'AVENIDA AVDA. DE LA CABRERA S/N JUNTO AL HOSTAL EL CANCHO DEL '
#              'AGUILA (A-1 KM 60), S/N',
#              'AVENIDA CASTILLA LA MANCHA',
#              'AVENIDA CONSTITUCION',
#              'AVENIDA DE CASTILLA LA MANCHA 54 (TO-413 km 33)',
#              'AVENIDA DE LA CIRCUNVALACION',
#              'AVENIDA DE LA TECNICA, S/N',
#              'AVENIDA EUROPA (C.C. LA MORALEJA), 13/15',
#              'AVENIDA FUENLABRADA',
#              'AVENIDA FUENTENUEVA',
#              'AVENIDA HISPANIDAD',
#              'AVENIDA LA INDUSTRIA, S/N',
#              'AVENIDA MADRID',
#              'AVENIDA PESETA',
#              'AVENIDA PORTUGAL (DE)',
#              'AVENIDA PORTUGAL (IZDO)',
#              'AVENIDA QUITAPESARES',
#              'AVENIDA RIO DUERO',
#              'AVENIDA RIO GUADALQUIVIR',
#              'AVENIDA SAN PABLO',
#              'AVENIDA TOLEDO',
#              'AVENIDA VALDELAPARRA (DE)'},
#  'Acacias': {'Acacias'},
#  'Acceso': {'Acceso Parque de la Elipa', 'Acceso a la Colonia Marconi'},
#  'Aguacate': {'Aguacate'},
#  'Aguado': {'Aguado'},
#  'Albala': {'Albala'},
#  'Albert': {'Albert Amon'},
#  'Alcocer': {'Alcocer, 23'},
#  'Alegría': {'Alegría de Oria'},
#  'Alexander': {'Alexander Graham Bell'},
#  'Alfonso': {'Alfonso XII'},
#  'Almíbar': {'Almíbar'},
#  'Alonso': {'Alonso Cano'},
#  'Amnistía': {'Amnistía'},
#  'Amor': {'Amor de Dios'},
#  'Amparo': {'Amparo'},
#  'Antigua': {'Antigua Carretera de Barcelona Km.'},
#  'Antonio': {'Antonio Buero Vallejo', 'Antonio Van de Pere'},
#  'Aragón': {'Aragón'},
#  'Argumosa': {'Argumosa'},
#  'Auditorio': {'Auditorio Sebastián Cesteros'},
#  'Av.': {'Av. Juan XXIII',
#          'Av. de los Arces',
#          'Av. de los Ébanos',
#          'Av.Juan Carlos I'},
#  'Avd': {'Avd Conde de Romanones'},
#  'Avd.': {'Avd. Juan Carlos I'},
#  'Avda': {'Avda Juan Carlos I s/n, Parking exterior junto recogida de compras '
#           'Alcampo',
#           'Avda Valderremata s/n.',
#           'Avda de Miguel Hernández',
#           'Avda de la Estación',
#           'Avda de la Hispanidad 20'},
#  'Avda.': {'Avda. Covibar',
#            'Avda. Gran Bretaña',
#            'Avda. Juan Carlos I',
#            'Avda. Madrid',
#            'Avda. Vicálvaro esq. Pobladura del Valle',
#            'Avda. de la Constitución',
#            'Avda. de la Ilustración',
#            'Avda. de la Paloma',
#            'Avda. de los Arqueros',
#            'Avda. del Pardo'},
#  'Avenidad': {'Avenidad de las Arcas del Agua'},
#  'Batalla': {'Batalla del Salado'},
#  'Bordadores': {'Bordadores'},
#  'Brasil': {'Brasil, 4', 'Brasil, 6'},
#  'Bruselas': {'Bruselas'},
#  'Bucarmanga': {'Bucarmanga'},
#  'C': {'C/',
#        'C/ Arroyo Salcedo',
#        'C/ CAMPEZO, 7 km CENTRO COMERCIAL M',
#        'C/ CTRA. ANDALUCÍA',
#        'C/ Don José Ingles',
#        'C/ José Bergamín',
#        'C/ Parque Grande',
#        'C/ San Joaquín nº5',
#        'C/ Severo Ochoa',
#        'C/ Sur',
#        'C/ Tiziano (Parque Urb. Felipe II )',
#        'C/. SAN PEDRO',
#        'C/Calderón Montero Ríos',
#        'C/Las Pozas, s/n - P.I. Matacuervos'},
#  'C.': {'C. C. LUZ DE CASTILLA - CTRA. DE SAN RAFAEL, N- 603',
#         'C.N.-603-MARGEN DERECHO km 93.60000',
#         'C.N.-603-MARGEN IZQUIERDO km 93.60000'},
#  'CALLE': {'CALLE ALCALA',
#            'CALLE ARAGON',
#            'CALLE ARTURO DUPERIER, S/N',
#            'CALLE CAMINO DE LA FABRICA, S/N',
#            'CALLE CAMINO LEGANES',
#            'CALLE CAMINO PORTASAGO, S/N',
#            'CALLE CARDENAL GONZÁLEZ DE MENDOZA, S/N',
#            'CALLE CARRETERA SAN RAFAEL',
#            'CALLE CERRO SAN PEDRO',
#            'CALLE COPENHAGUES/N, S/N',
#            'CALLE CTRA. OCAÑA',
#            'CALLE DOCTOR CABAÑAS',
#            'CALLE EBANISTAS,',
#            'CALLE EXTRAMUROS, S/N',
#            'CALLE FELIPE CALLEJA, S/N',
#            'CALLE FRANCISCO ARITIO, S/N',
#            'CALLE FRANCISCO MEDINA Y MENDOZA, P.4-18',
#            'CALLE GENERALISIMO',
#            'CALLE HERNANDEZ TEJADA, S/N ESQ. AGASTIA, S/N (A-2 KM 5.1), S,N',
#            'CALLE I',
#            'CALLE INMACULADA',
#            'CALLE JULIAN BESTEIRO, S/N',
#            'CALLE LUIS SAUQUILLO',
#            'CALLE NARCISO MONTURIOL',
#            'CALLE NAVALPINO',
#            'CALLE NUEVA, S/N',
#            'CALLE PEDRO GARRIDO, S/N',
#            'CALLE PUENTE SAN ROQUE',
#            'CALLE REAL, S/N',
#            'CALLE SANTA MISION',
#            'CALLE SEGOVIA C/V A PASEO VIRGEN DEL PUERTO, S/N',
#            'CALLE SESEÑA'},
#  'CAMINO': {'CAMINO SAN MARTIN CTRA. FONTANAR', 'CAMINO DEL VENTORRILLO, S/N'},
#  'CARRERA': {'CARRERA CARRETERA DE CRIÑON, S/N', 'CARRERA VALENCIA, KM 14.800'},
#  'CARRETERA': {'CARRETERA ANDALUCIA KM 28.230',
#                'CARRETERA ANTIGUA NACIONAL I KM 15.5',
#                'CARRETERA ARANJUEZ- ONTIGOLA KM 2.700',
#                'CARRETERA C L 605 DE SEGOVIA A ZAMORA KM. 14',
#                'CARRETERA C-302 KM 38.40',
#                'CARRETERA C-404 KM. 28',
#                'CARRETERA CABANILLAS A BUSTARVIEJO KM 5.320',
#                'CARRETERA CARRETERA TOLEDO KM 80.250',
#                'CARRETERA CL-601 KM 100.800',
#                'CARRETERA CM-101 KM. 0',
#                'CARRETERA CM-4000 KM 2.650',
#                'CARRETERA CM-4004 KM 17.50',
#                'CARRETERA CM-4006 P.IND. SECTOR 12 PARCELAS 38 A 41 KM. S/N',
#                'CARRETERA CM-4010 KM. 2',
#                'CARRETERA COMARCAL 400 KM 2.810',
#                'CARRETERA COMARCAL M236 KM 51.600',
#                'CARRETERA CTRA.N-301 KM. 67',
#                'CARRETERA DE TORREJON A LOECHES KM 1.100',
#                'CARRETERA FONTANAR KM. 1',
#                'CARRETERA FUENCEMILLAN-ESPINOSA S/N (CARRETERA km 38)',
#                'CARRETERA L 54 KM. 7',
#                'CARRETERA M 506 KM 4.900',
#                'CARRETERA M-233 KM 6.800',
#                'CARRETERA M-300 KM 8.1',
#                'CARRETERA M-300 KM. 13',
#                'CARRETERA M-305 KM. 5',
#                'CARRETERA M-311 KM 19.4',
#                'CARRETERA M-404 KM 39.8',
#                'CARRETERA M-404 KM. 31',
#                'CARRETERA M-405 KM 5.6',
#                'CARRETERA M-405 KM. 6',
#                'CARRETERA M-501 KM 17.2',
#                'CARRETERA M-501 KM 40.500',
#                'CARRETERA M-501 KM. 27',
#                'CARRETERA M-505 km 5.5',
#                'CARRETERA M-506 KM. 4',
#                'CARRETERA M-507 KM 6.700',
#                'CARRETERA M-509 KM 4.4',
#                'CARRETERA M-515 KM. 2',
#                'CARRETERA M-600 KM. 14',
#                'CARRETERA M-604 KM 14.100',
#                'CARRETERA M-610 KM 19.8',
#                'CARRETERA M-623 KM 1.5',
#                'CARRETERA M208 KM 9.600',
#                'CARRETERA M222 KM. 19',
#                'CARRETERA M506 PK 26 KM. 26',
#                'CARRETERA MADRID-TOLEDO KM 57.700',
#                'CARRETERA N-110 A SORIA KM 189 PARKING SUPERMERCADO KM. 110',
#                'CARRETERA N-110 KM 182.650',
#                'CARRETERA N-320 KM 303.6',
#                'CARRETERA N-320 KM 314.500',
#                'CARRETERA N-400 KM 24.6',
#                'CARRETERA N-403 KM 17.300',
#                'CARRETERA N-II KM. 38',
#                'CARRETERA N-V KM. 40',
#                'CARRETERA N-VI KM 43.2',
#                'CARRETERA TOLEDO -CUESTA LA REINA KM 10.200',
#                'CARRETERA TOLEDO-MOCEJON KM 4.300',
#                'CARRETERA VALDEMAQUEDA KM. 0'},
#  'CC.': {'CC. LORANCA ALCAMPO FUENLABRADA (AV. PABLO IGLESIAS, S/N, CIUDAD '
#          'LORANCA)'},
#  'CERRO': {'CERRO DE LA VEGA, S/N.'},
#  'CL': {'CL ALAMO, PL INDS LOS HUERTECILLO 49 (AV DE LA CONSTITUCION 167)',
#         'CL AV DE LA INDUSTRIA',
#         'CL AVDA. S. MARTIN DE VALDEIGLE, S. (M-501 KM 0.3)',
#         'CL AVENIDA ALCALA',
#         'CL AVENIDA CASTILLA LA MANCHA, 79 (N-401 KM 35.5)',
#         'CL BARLOVENTO',
#         'CL BOULEVARD SALVADOR ALLENDE, 12-1',
#         'CL CALVARIO 10',
#         'CL CARRETERA ARANJUEZ ,56 (CR M-305 (M-305 KM 19.8)',
#         'CL DR.MARAÑON C/V PL ESCORIAL, S.N.',
#         'CL FRANCISCO ARITIO  97',
#         'CL FRAY JOSE DE SAN JACINTO 10',
#         'CL JARAMA (POLG. INDUST.PAR,22), S.',
#         'CL MADRID',
#         'CL PASEO EZEQUIEL GONZALEZ',
#         'CL PASEO GALATEA, 35 (TO-423 KM 10.9)',
#         'CL-601 (VALLADOLID-SEGOVIA) km 105',
#         'CL-605 km 1'},
#  'CL.': {'CL.AGUILAS (P. IND. PINTO ESTACIÓN)'},
#  'CM': {'CM-4001',
#         'CM-4001 km 23',
#         'CM-4003',
#         'CM-4003 km P.K.32,4',
#         'CM-4009 km P.K.14,4'},
#  'CR': {'CR A-3 MG IZDO, KM 11.2 KM 11.200',
#         'CR A-42 P.K. 63,30 D',
#         'CR A-42, 32,8',
#         'CR A-42, 42,8',
#         'CR A-42, 47,3',
#         'CR A-42, 63,30 I',
#         'CR A-5',
#         'CR A-5, 23.5',
#         'CR ALGETE KM 5.80',
#         'CR C-9, 31 (C-9 KM 31.4)',
#         'CR CM-1002 P.K. 26,70 D',
#         'CR CM-219, 4,9',
#         'CR CM-401, 9,2 M.D.',
#         'CR GU-102, Km. 2.350 ',
#         'CR M-103, 23,5',
#         'CR M-214, 4,6',
#         'CR M-300, 30.3',
#         'CR M-406 , P.K. 7,3',
#         'CR M-406 KM 10',
#         'CR M-506',
#         'CR M-506 MOSTOLES-FUENLABRADA KM. 4',
#         'CR M-603, 14,1',
#         'CR M-856 (ENLACE N-V Y N-501) km 1',
#         'CR MOSTOLES-FUENLABRADA, KM.4',
#         'CR N-4 P.K. 6,70 D',
#         'CR N-4 P.K. 6,70 I',
#         'CR N-400, 56,8',
#         'CR PARLA-PINTO, KM. 0.15'},
#  'CR.': {'CR.VILLALUENGA-COBEJA (TO-4512-V km P.K.2,0)'},
#  'CRTA.': {'CRTA. N-III PK. 41,00', 'CRTA. N-I KM 14.5'},
#  'CTRA': {'CTRA MADRID-BADAJOZ N-5 KM 57.6',
#           'CTRA, N-V km 37550',
#           'CTRA: M-218 ESQ. C/ DUERO - POLÍGONO INDUSTRIAL'},
#  'CTRA.': {'CTRA. 607 (DE COLMENAR A NAVACERRADA) KM 48.2',
#            'CTRA. BOADILLA KM 1.0',
#            'CTRA. BURGOS',
#            'CTRA. FUENLABRADA-HUMANES S/N',
#            'CTRA. M-505 KM 5.5',
#            'CTRA. MADRID TOLEDO km 10',
#            'CTRA. N-I KM 64.650',
#            'CTRA. N-IV km 32',
#            'CTRA. N-V KM 12.5',
#            'CTRA. NACIONAL V, (el soto) KM 19.0',
#            'CTRA. TOLEDO-BARGAS, KM 1.700',
#            'CTRA. VILLAVERDE-VALLECAS'},
#  'Cabo': {'Cabo Estaca de Bares', 'Cabo Rufino Lázaro'},
#  'Call': {'Call de la Hermandad de Donantes Sangre'},
#  'Calleja': {'Calleja A',
#              'Calleja de Cavanilles',
#              'Calleja del Potro',
#              'Calleja del Potro ',
#              'Calleja/Callejï¿½ï¿½n Callejon-alpedrete',
#              'Calleja/Callejï¿½ï¿½n Tabernillas',
#              'Calleja/Callejï¿½ï¿½n Viento'},
#  'Callejuela': {'Callejuela de la Clínica'},
#  'Callejón': {'Callejón Cubillo de San Vicente',
#               'Callejón Dos Codos',
#               'Callejón Eras',
#               'Callejón Gómez Acebo',
#               'Callejón Lucio',
#               'Callejón Menores',
#               'Callejón Siete Chimeneas',
#               'Callejón Sillería',
#               'Callejón Tabernillas',
#               'Callejón Vaquero',
#               'Callejón de Antequeruela',
#               'Callejón de García Cea',
#               'Callejón de Gómez Acebo',
#               'Callejón de Jesús',
#               'Callejón de Jorge Juan',
#               'Callejón de Juan de Mata Gómez',
#               'Callejón de Murcia',
#               'Callejón de Ordoñez',
#               'Callejón de Ordóñez',
#               'Callejón de Preciados',
#               'Callejón de San Ginés',
#               'Callejón de la Concepción Jerónima',
#               'Callejón de la Cruz',
#               'Callejón de la Huerta',
#               'Callejón de la Luz',
#               'Callejón de las Santas Formas',
#               'Callejón del Alamillo',
#               'Callejón del Arrabal del Hoyo',
#               'Callejón del Chorrillo',
#               'Callejón del Mellizo',
#               'Callejón del Molino',
#               'Callejón del Potro'},
#  'Calvario': {'Calvario'},
#  'Camilo': {'Camilo José Cela', 'Camilo Jose Cela'},
#  'Campezo': {'Campezo'},
#  'Campus': {'Campus de Somosagua, Ctra. de Húmera, s/n, Pozuelo de Alarcón, '
#             'Madrid'},
#  'Cardenal': {'Cardenal Cisneros'},
#  'Carmen': {'Carmen Martín Gaite'},
#  'Carre': {'Carre de las Moreras'},
#  'Carrterera': {'Carrterera de El Plantío'},
#  'Casas': {'Casas de Miravete'},
#  'Castiello': {'Castiello De Jaca'},
#  'Castilla': {'Castilla'},
#  'Cataluña': {'Cataluña'},
#  'Cava': {'Cava de San Miguel'},
#  'Cañada': {'Cañada de San Marcos', 'Cañada Real Galiana', 'Cañada'},
#  'Centro': {'Centro Comercial Getafe 3'},
#  'Charco': {'Charco'},
#  'Chiapas': {'Chiapas'},
#  'Cid': {'Cid Campeador'},
#  'Circunvalación': {'Circunvalación (Posterior)'},
#  'Ciudad': {'Ciudad Jardín del Rosario'},
#  'Comandante': {'Comandante Fontanes'},
#  'Comunidad': {'Comunidad de Madrid'},
#  'Concejo': {'Concejo/Colegio Ejercito de Tierra'},
#  'Concilios': {'Concilios de Toledo'},
#  'Conde': {'Conde Duque'},
#  'Condesa': {'Condesa del Venadito'},
#  'Constitución': {'Constitución'},
#  'Corral': {'Corral de la Sinagoga'},
#  'Coscinia': {'Coscinia'},
#  'Crisalida': {'Crisalida'},
#  'Cristo': {'Cristo del Pardo'},
#  'Crta': {'Crta 607'},
#  'Crta.': {'Crta. de Ugena', 'Crta. M600 De Valdemorillo a El Escorial'},
#  'Ctra': {'Ctra Las Rozas - El Escorial',
#           'Ctra de la Granja',
#           'Ctra del Pardo'},
#  'Ctra.': {'Ctra. Algete-Alalpardo',
#            'Ctra. CL-601 Segovia a San Ildefonso',
#            'Ctra. De Algete, Km 1 (desvío Km. 23 de la N-1) San Sebastián de '
#            'los Reyes',
#            'Ctra. Fuensalida - Torrijos',
#            'Ctra. N-601',
#            'Ctra. N-IV KM 55.200',
#            'Ctra. Piedrabuena',
#            'Ctra. Villalba a Moralzarzal',
#            'Ctra. de Bustarviejo, 26',
#            'Ctra. de Extremadura',
#            'Ctra. de Robledo de Chabela',
#            'Ctra. de la Coruña',
#            'Ctra.Moralzarzal'},
#  'Cuzco': {'Cuzco'},
#  'DIAZ': {'DIAZ CORDOBES, S/N.'},
#  'Daoiz': {'Daoiz y Velarde'},
#  'Disem': {'Disem de Colmenar de Oñoro'},
#  'Diseminados': {'Diseminados Diseminados',
#                  'Diseminados Ds.resto Municipio',
#                  'Diseminados Pingarron'},
#  'Divino': {'Divino Pastor (entrada por San Andrés)'},
#  'Dos': {'Dos Amigos'},
#  'El': {'El Pardo a Colmenar Viejo'},
#  'Elfo': {'Elfo'},
#  'Embajadores': {'Embajadores'},
#  'Emilio': {'Emilio Gastesi Fernández'},
#  'Entrada': {'Entrada a la Sala de Exposiciones'},
#  'Eric': {'Eric Kandel'},
#  'España': {'España'},
#  'Espinar': {'Espinar 1'},
#  'Estocolmo': {'Estocolmo'},
#  'Estrella': {'Estrella Polar'},
#  'Eugenio': {'Eugenio Sellés'},
#  'FIXME': {'FIXME Avenida La Verbena De La Paloma',
#            'FIXME FUENTE DEL BERRO, CALLE, DE LA',
#            'FIXME IBIZA, CALLE, DE',
#            'FIXME Paseo San Francisco De Sales'},
#  'Fabián': {'Fabián Lorente'},
#  'Faraday': {'Faraday'},
#  'Federica': {'Federica Montseny'},
#  'Federico': {'Federico Moreno Torroba', 'Federico Salmón'},
#  'Fermín': {'Fermín Caballero'},
#  'Fernando': {'Fernando de Rojas'},
#  'Finca': {'Finca Tirabuey'},
#  'Fontanilla': {'Fontanilla'},
#  'Fornells': {'Fornells'},
#  'Francisco': {'Francisco Ayala, 1', 'Francisco Javier Sauquillo'},
#  'Fuencarral': {'Fuencarral'},
#  'Fuenlabrada': {'Fuenlabrada'},
#  'Fundidores': {'Fundidores'},
#  'GLORIETA': {'GLORIETA LOS JAZMINES, S/N'},
#  'Gavilán': {'Gavilán\n'},
#  'General': {'General Aranaz',
#              'General Asensio Cabanillas',
#              'General Ibáñez de Ibero',
#              'General Lacy',
#              'General Ricardos',
#              'General Ricardos, 175'},
#  'Gerardo': {'Gerardo Diego'},
#  'Ginebra': {'Ginebra'},
#  'Gobernador': {'Gobernador Fernández Jiménez'},
#  'Gran': {'Gran Vía', 'Gran Bretaña', 'Gran Vía de San Francisco'},
#  'Grecia': {'Grecia'},
#  'Guzmán': {'Guzmán el Bueno'},
#  'Herencia': {'Herencia'},
#  'Hermandad': {'Hermandad de Donantes de Sangre', 'Hermandad Donantes Sangre'},
#  'Honduras': {'Honduras'},
#  'Huesca': {'Huesca'},
#  'IES': {'IES Sapere Aude'},
#  'Isla': {'Isla de Lobeira', 'Isla Graciosa'},
#  'JAEN': {'JAEN'},
#  'Jacinto': {'Jacinto Verdaguer'},
#  'Joaquín': {'Joaquín Turina'},
#  'José': {'José Echegaray', 'José Hierro'},
#  'Juan': {'Juan Alvarez Mendizaba',
#           'Juan Guerra',
#           'Juan Ramon Jimenez',
#           'Juan de Toledo'},
#  'Julian': {'Julian Camarillo'},
#  'Kalamos': {'Kalamos'},
#  'L': {'L-14 OCAÑA-PTE. PEDRERA KM 39.5'},
#  'La': {'La Mequera', 'La Torre', 'La Venta'},
#  'Leopoldo': {'Leopoldo Alas "Clarín"'},
#  'Lilí': {'Lilí Álvarez'},
#  'Lina': {'Lina de Avila'},
#  'Lisboa': {'Lisboa'},
#  'Londres': {'Londres'},
#  'Lope': {'Lope de Vega'},
#  'Los': {'Los Frailes', 'Los Ánegles', 'Los Lecheros'},
#  'Luis': {'Luis Sauquillo', 'Luis de Medina'},
#  'López': {'López de Hoyos'},
#  'M': {'M-100',
#        'M-103 km 6.207',
#        'M-103 km 6.210',
#        'M-203 (MADRID-VICALVARO) km 3600',
#        'M-208 KM 3.8',
#        'M-300 Carretera Alcalá-Loeches',
#        'M-40, PK 7.4 - ACCESO AL CAMPO DE LAS NACIONES',
#        'M-505 KM 15.5',
#        'M-603 (FUENCARRAL - ALCOBENDAS) KM 14.9',
#        'M-608 km 38',
#        'M-832'},
#  'Madrid': {'Madrid'},
#  'Maria': {'Maria de Molina'},
#  'Mariano': {'Mariano Saiz'},
#  'Marie': {'Marie Curie'},
#  'Marmolistas': {'Marmolistas'},
#  'Martin': {'Martin Iriarte'},
#  'Martínez': {'Martínez Villergas'},
#  'María': {'María Tubau'},
#  'Matacerquillas': {'Matacerquillas'},
#  'Matadero': {'Matadero'},
#  'Mayor': {'Mayor'},
#  'Mercado': {'Mercado de Barceló'},
#  'Miguel': {'Miguel de Cervantes', 'Miguel Ángel'},
#  'Montamarta': {'Montamarta'},
#  'Motilla': {'Motilla del Palancar'},
#  'Musgo': {'Musgo'},
#  'N': {'N-400 KM 82.4', 'N-II KM 29.000'},
#  'NACIONAL': {'NACIONAL 320 km 276'},
#  'Narciso': {'Narciso Monturiol'},
#  'Néctar': {'Néctar'},
#  'Orquídea': {'Orquídea'},
#  'Oslo': {'Oslo'},
#  'Oña': {'Oña'},
#  'PASEO': {'PASEO DE LA ERMITA, S/N.',
#            'PASEO DE LA HERMITA DE STA. ANA',
#            'PASEO ESTACION, S/N',
#            'PASEO JUNCAREJO/CL DE AGORA'},
#  'PLAZA': {'PLAZA MORALEJA S/N, S/N', 'PLAZA HUERTA DE LAS FLORES'},
#  'POL.': {'POL. IND. VALDELASILLA - C.C. CAPRABO'},
#  'POLIGONO': {'POLIGONO ALPARACHE, S/N',
#               'POLIGONO CENTRO LOGISTICO DE ABASTECIMIENTO-PARCELA',
#               'POLIGONO FRANCISCO MEDINA Y MENDOZA PARCELA 10, S/N',
#               'POLIGONO INDUSRIAL PINARES LLANOS, C/CARPINTEROS, S/N',
#               'POLIGONO INDUSTRIAL BOADILLA PARCELAS 2-3-4, S/N',
#               'POLIGONO LA CARBONERA, S/N'},
#  'Padrón': {'Padrón'},
#  'Palazuelos': {'Palazuelos de Eresma'},
#  'Palmera': {'Palmera'},
#  'Paloma': {'Paloma'},
#  'Palos': {'Palos de la Frontera'},
#  'Pamplona': {'Pamplona'},
#  'Paraje': {'Paraje Pontezuela', 'Paraje de la Dehesa'},
#  'Pasadizo': {'Pasadizo de San Ginés'},
#  'Pasage': {'Pasage de Matheu'},
#  'Pedro': {'Pedro Gumiel', 'Pedro de Valdivia'},
#  'Pez': {'Pez Austral'},
#  'Pico': {'Pico de la cierva'},
#  'Pinos': {'Pinos Alta'},
#  'Pintor': {'Pintor Rivera, 1 posterior', 'Pintor Murillo', 'Pintor Velazquez'},
#  'Pista': {'Pista multijuegos', 'Pista Cristo del Pardo'},
#  'Pizarro': {'Pizarro'},
#  'Plaseo': {'Plaseo de las Acacias'},
#  'Pobladura': {'Pobladura del Valle'},
#  'Polï': {'Polï¿½ï¿½gono Vpv.016.pt.ciudad Ocio', 'Polï¿½ï¿½gono Vp Arpo'},
#  'Pretil': {'Pretil de Santiesteban'},
#  'Princesa': {'Princesa de Éboli'},
#  'Proción': {'Proción'},
#  'Profesor': {'Profesor Waksman 6', 'Profesor Waksman, 5'},
#  'Prolongación': {'Prolongación Calle de Jorge Guillén'},
#  'Príncipe': {'Príncipe de Vergara'},
#  'Puerta': {'Puerta del Sol', 'Puerta del Cambrón', 'Puerta de Abajo'},
#  'Pz': {'Pz San Antonio de la Florida'},
#  'Pz.': {'Pz. Sta Mª de la Cabeza'},
#  'Pza.': {'Pza. Epifanio Velasco'},
#  'Pío': {'Pío Baroja'},
#  'Quitapesares': {'Quitapesares'},
#  'ROSA': {'ROSA DE LIMA'},
#  'Rafaela': {'Rafaela Aparicio', 'Rafaela Ybarra'},
#  'Rcda': {'Rcda Carrasquilla', 'Rcda Bernaldo de Quirós', 'Rcda San Francisco'},
#  'Real': {'Real'},
#  'Recodo': {'Recodo del Pinar'},
#  'Rector': {'Rector Royo Villanova'},
#  'Reina': {'Reina Sofía'},
#  'Ribera': {'Ribera de Curtidores'},
#  'Rinconada': {'Rinconada Magdalena',
#                'Rinconada de Juan del Campo',
#                'Rinconada de la Estrella'},
#  'Rosario': {'Rosario Romero'},
#  'Rotonda': {'Rotonda de Pitágoras'},
#  'Rufino': {'Rufino González'},
#  'Río': {'Río Tormes'},
#  'SAN': {'SAN BERNARDO, S/N - Bº DE LA FORTUNA'},
#  'Salida': {'Salida de San Andrés'},
#  'Salvador': {'Salvador Sanchez Frascuelo'},
#  'Samaniego': {'Samaniego'},
#  'Sambara': {'Sambara'},
#  'San': {'San Vidal', 'San Cipriano', 'San Agustin', 'San Andrés'},
#  'Santa': {'Santa Engracia', 'Santa Isabel'},
#  'Santander': {'Santander'},
#  'Saturnia': {'Saturnia'},
#  'Sector': {'Sector Caraquiz',
#             'Sector Fray José de Almonacid',
#             'Sector Literatos 3.',
#             'Sector Músicos'},
#  'Septiembre': {'Septiembre'},
#  'Serrano': {'Serrano'},
#  'Severo': {'Severo Ochoa'},
#  'Sierra': {'Sierra Morena'},
#  'Silvano': {'Silvano'},
#  'Sor': {'Sor Juana Inés de la Cruz', 'Sor Livia Alcorta'},
#  'TO': {'TO-4421-V km P.K.10,2'},
#  'TR': {'TR DEL DESVIO 19'},
#  'Talleres': {'Talleres mecánicos González'},
#  'Taray': {'Taray'},
#  'Tarragona': {'Tarragona'},
#  'Telecomunicaciones': {'Telecomunicaciones'},
#  'Tenerife': {'Tenerife'},
#  'Teniente': {'Teniente Ruiz'},
#  'Topete': {'Topete'},
#  'Travesia': {'Travesia Bravo Murillo',
#               'Travesia Calle Ancha',
#               'Travesia Colombia',
#               'Travesia Conde Duque',
#               'Travesia Paloma',
#               'Travesia de la Comadre'},
#  'Travesï': {'Travesï¿½ï¿½a Alta-alpedrete',
#              'Travesï¿½ï¿½a Santiago',
#              'Travesï¿½ï¿½a Travesia A'},
#  'Travesïa': {'Travesïa Primer'},
#  'Tunel': {"Tunel O'Donnell"},
#  'Turín': {'Turín'},
#  'Urb.': {'Urb. Bellavista',
#           'Urb. Los LLanos',
#           'Urb. ParqueSierra',
#           'Urb. Pryconsa'},
#  'Urbanización': {'Urbanización Casablanca',
#                   'Urbanización Gran Hábitat',
#                   'Urbanización Los Enebros',
#                   'Urbanización Montenebros I',
#                   'Urbanización Montenebros II',
#                   'Urbanización Noria de la Paz',
#                   'Urbanización Nuevo Versalles',
#                   'Urbanización Princialba',
#                   'Urbanización Santos Niños',
#                   'Urbanización Semisierra',
#                   'Urbanización Tres Culturas',
#                   'Urbanización Venecia',
#                   'Urbanización Villalba 20'},
#  'Valderrey': {'Valderrey'},
#  'Valderromán': {'Valderromán'},
#  'Vale': {'Vale de Eusebio Blasco'},
#  'Valparaíso': {'Valparaíso'},
#  'Van': {'Van Gogh'},
#  'Venezuela': {'Venezuela'},
#  'Ventura': {'Ventura Rodríguez'},
#  'Verdad': {'Verdad'},
#  'Vereda': {'Vereda Gansino', 'Vereda del Altozano', 'Vereda del Valle'},
#  'Veredilla': {'Veredilla'},
#  'Via': {'Via De Los Poblados',
#          'Via de Servicio, 19',
#          'Via de las Dos Castillas',
#          'Via de las dos Castillas'},
#  'Viario': {'Viario de Ronda'},
#  'Victoria': {'Victoria Kent'},
#  'Viena': {'Viena'},
#  'Violeta': {'Violeta'},
#  'Virgen': {'Virgen de Nuria',
#             'Virgen de la Alegría',
#             'Virgen de la Hoz',
#             'Virgen de la Providencia',
#             'Virgen del Amparo',
#             'Virgen del Canto',
#             'Virgen del Coro',
#             'Virgen del Pilar',
#             'Virgen del Sagrario'},
#  'Yeros': {'Yeros'},
#  'ZONA': {'ZONA AEROPUERTO DE BARAJAS, T4, S/N',
#           'ZONA AEROPUERTO DE BARAJAS, TERMINAL 2, S/N',
#           'ZONA PLATAFORMA AEROPUERTO BARAJAS T123, S/N'},
#  'Zerynthia': {'Zerynthia'},
#  'Zurbarán': {'Zurbarán '},
#  'calle': {'calle De los Alamillos, 13. Toledo',
#            'calle Dulcinea del Toboso',
#            'calle Mayor',
#            'calle Tokio',
#            'calle de Benito Monfort',
#            'calle de la Pintora Ángeles Santos',
#            'calle de los Alamillos '},
#  'callejón': {'callejón del Clavel'},
#  'crta': {'crta de Galapagar a Villalba M-528'},
#  'del': {'del Ferrocarril'},
#  'encinas': {'encinas'},
#  'espinos': {'espinos'},
#  'gloria': {'gloria fuertes'},
#  'http': {'http://uj3wazyk5u4hnvtk.onion/'},
#  'ladera': {'ladera del chorrillo'},
#  'pitano': {'pitano'},
#  'plaza': {'plaza Tingo Maria 12',
#            'plaza de Castilla',
#            'plaza de Manuel Marchamalo'},
#  'uvas': {'uvas'},
#  'zarzuela': {'zarzuela'}}
# Fuencarral => Fuencarral
# Pasadizo de San Ginés => Pasadizo de San Ginés
# Gran Vía => Gran Vía
# Gran Bretaña => Gran Bretaña
# Gran Vía de San Francisco => Gran Vía de San Francisco
# Julian Camarillo => Julian Camarillo
# http://uj3wazyk5u4hnvtk.onion/ => http://uj3wazyk5u4hnvtk.onion/
# gloria fuertes => gloria fuertes
# Av. de los Ébanos => Avenida de los Ébanos
# Av. de los Arces => Avenida de los Arces
# Av. Juan XXIII => Avenida Juan XXIII
# Av.Juan Carlos I => Av.Juan Carlos I
# José Echegaray => José Echegaray
# José Hierro => José Hierro
# Campezo => Campezo
# CR A-42, 47,3 => Carretera A-42, 47,3
# CR N-4 P.K. 6,70 D => Carretera N-4 P.K. 6,70 D
# CR N-4 P.K. 6,70 I => Carretera N-4 P.K. 6,70 I
# CR ALGETE KM 5.80 => Carretera ALGETE KM 5.80
# CR M-214, 4,6 => Carretera M-214, 4,6
# CR CM-1002 P.K. 26,70 D => Carretera CM-1002 P.K. 26,70 D
# CR M-406 KM 10 => Carretera M-406 KM 10
# CR GU-102, Km. 2.350  => Carretera GU-102, Km. 2.350
# CR CM-401, 9,2 M.D. => Carretera CM-401, 9,2 M.D.
# CR M-103, 23,5 => Carretera M-103, 23,5
# CR N-400, 56,8 => Carretera N-400, 56,8
# CR M-300, 30.3 => Carretera M-300, 30.3
# CR CM-219, 4,9 => Carretera CM-219, 4,9
# CR MOSTOLES-FUENLABRADA, KM.4 => Carretera MOSTOLES-FUENLABRADA, KM.4
# CR A-42, 63,30 I => Carretera A-42, 63,30 I
# CR M-856 (ENLACE N-V Y N-501) km 1 => Carretera M-856 (ENLACE N-V Y N-501) km 1
# CR A-42, 32,8 => Carretera A-42, 32,8
# CR A-5 => Carretera A-5
# CR M-406 , P.K. 7,3 => Carretera M-406 , P.K. 7,3
# CR PARLA-PINTO, KM. 0.15 => Carretera PARLA-PINTO, KM. 0.15
# CR A-3 MG IZDO, KM 11.2 KM 11.200 => Carretera A-3 MG IZDO, KM 11.2 KM 11.200
# CR M-603, 14,1 => Carretera M-603, 14,1
# CR M-506 MOSTOLES-FUENLABRADA KM. 4 => Carretera M-506 MOSTOLES-FUENLABRADA KM. 4
# CR A-42 P.K. 63,30 D => Carretera A-42 P.K. 63,30 D
# CR M-506 => Carretera M-506
# CR A-5, 23.5 => Carretera A-5, 23.5
# CR C-9, 31 (C-9 KM 31.4) => Carretera C-9, 31 (C-9 KM 31.4)
# CR A-42, 42,8 => Carretera A-42, 42,8
# CARRETERA ANTIGUA NACIONAL I KM 15.5 => Carretera ANTIGUA NACIONAL I KM 15.5
# CARRETERA M-506 KM. 4 => Carretera M-506 KM. 4
# CARRETERA M-505 km 5.5 => Carretera M-505 km 5.5
# CARRETERA N-V KM. 40 => Carretera N-V KM. 40
# CARRETERA N-VI KM 43.2 => Carretera N-VI KM 43.2
# CARRETERA M208 KM 9.600 => Carretera M208 KM 9.600
# CARRETERA FUENCEMILLAN-ESPINOSA S/N (CARRETERA km 38) => Carretera FUENCEMILLAN-ESPINOSA S/N (Carretera km 38)
# CARRETERA M-507 KM 6.700 => Carretera M-507 KM 6.700
# CARRETERA M222 KM. 19 => Carretera M222 KM. 19
# CARRETERA N-110 A SORIA KM 189 PARKING SUPERMERCADO KM. 110 => Carretera N-110 A SORIA KM 189 PARKING SUPERMERCADO KM. 110
# CARRETERA VALDEMAQUEDA KM. 0 => Carretera VALDEMAQUEDA KM. 0
# CARRETERA N-400 KM 24.6 => Carretera N-400 KM 24.6
# CARRETERA CARRETERA TOLEDO KM 80.250 => Carretera Carretera TOLEDO KM 80.250
# CARRETERA M-501 KM 17.2 => Carretera M-501 KM 17.2
# CARRETERA M-404 KM. 31 => Carretera M-404 KM. 31
# CARRETERA M-600 KM. 14 => Carretera M-600 KM. 14
# CARRETERA TOLEDO-MOCEJON KM 4.300 => Carretera TOLEDO-MOCEJON KM 4.300
# CARRETERA N-II KM. 38 => Carretera N-II KM. 38
# CARRETERA CTRA.N-301 KM. 67 => Carretera CTRA.N-301 KM. 67
# CARRETERA COMARCAL M236 KM 51.600 => Carretera COMARCAL M236 KM 51.600
# CARRETERA M-501 KM. 27 => Carretera M-501 KM. 27
# CARRETERA M-300 KM 8.1 => Carretera M-300 KM 8.1
# CARRETERA M-610 KM 19.8 => Carretera M-610 KM 19.8
# CARRETERA FONTANAR KM. 1 => Carretera FONTANAR KM. 1
# CARRETERA CM-4004 KM 17.50 => Carretera CM-4004 KM 17.50
# CARRETERA M-405 KM 5.6 => Carretera M-405 KM 5.6
# CARRETERA M-233 KM 6.800 => Carretera M-233 KM 6.800
# CARRETERA ARANJUEZ- ONTIGOLA KM 2.700 => Carretera ARANJUEZ- ONTIGOLA KM 2.700
# CARRETERA CM-4000 KM 2.650 => Carretera CM-4000 KM 2.650
# CARRETERA M-305 KM. 5 => Carretera M-305 KM. 5
# CARRETERA TOLEDO -CUESTA LA REINA KM 10.200 => Carretera TOLEDO -CUESTA LA REINA KM 10.200
# CARRETERA L 54 KM. 7 => Carretera L 54 KM. 7
# CARRETERA COMARCAL 400 KM 2.810 => Carretera COMARCAL 400 KM 2.810
# CARRETERA MADRID-TOLEDO KM 57.700 => Carretera MADRID-TOLEDO KM 57.700
# CARRETERA C-404 KM. 28 => Carretera C-404 KM. 28
# CARRETERA M-311 KM 19.4 => Carretera M-311 KM 19.4
# CARRETERA CM-4010 KM. 2 => Carretera CM-4010 KM. 2
# CARRETERA ANDALUCIA KM 28.230 => Carretera ANDALUCIA KM 28.230
# CARRETERA CL-601 KM 100.800 => Carretera CL-601 KM 100.800
# CARRETERA N-320 KM 314.500 => Carretera N-320 KM 314.500
# CARRETERA M 506 KM 4.900 => Carretera M 506 KM 4.900
# CARRETERA CABANILLAS A BUSTARVIEJO KM 5.320 => Carretera CABANILLAS A BUSTARVIEJO KM 5.320
# CARRETERA M-509 KM 4.4 => Carretera M-509 KM 4.4
# CARRETERA M506 PK 26 KM. 26 => Carretera M506 PK 26 KM. 26
# CARRETERA DE TORREJON A LOECHES KM 1.100 => Carretera DE TORREJON A LOECHES KM 1.100
# CARRETERA M-404 KM 39.8 => Carretera M-404 KM 39.8
# CARRETERA N-320 KM 303.6 => Carretera N-320 KM 303.6
# CARRETERA M-515 KM. 2 => Carretera M-515 KM. 2
# CARRETERA C-302 KM 38.40 => Carretera C-302 KM 38.40
# CARRETERA CM-101 KM. 0 => Carretera CM-101 KM. 0
# CARRETERA M-623 KM 1.5 => Carretera M-623 KM 1.5
# CARRETERA M-604 KM 14.100 => Carretera M-604 KM 14.100
# CARRETERA M-300 KM. 13 => Carretera M-300 KM. 13
# CARRETERA CM-4006 P.IND. SECTOR 12 PARCELAS 38 A 41 KM. S/N => Carretera CM-4006 P.IND. SECTOR 12 PARCELAS 38 A 41 KM. S/N
# CARRETERA N-403 KM 17.300 => Carretera N-403 KM 17.300
# CARRETERA N-110 KM 182.650 => Carretera N-110 KM 182.650
# CARRETERA M-405 KM. 6 => Carretera M-405 KM. 6
# CARRETERA M-501 KM 40.500 => Carretera M-501 KM 40.500
# CARRETERA C L 605 DE SEGOVIA A ZAMORA KM. 14 => Carretera C L 605 DE SEGOVIA A ZAMORA KM. 14
# CTRA, N-V km 37550 => CTRA, N-V km 37550
# CTRA: M-218 ESQ. C/ DUERO - POLÍGONO INDUSTRIAL => CTRA: M-218 ESQ. Calle DUERO - POLÍGONO INDUSTRIAL
# CTRA MADRID-BADAJOZ N-5 KM 57.6 => Carretera MADRID-BADAJOZ N-5 KM 57.6
# CL MADRID => Calle MADRID
# CL PASEO EZEQUIEL GONZALEZ => Calle Paseo EZEQUIEL GONZALEZ
# CL AVENIDA ALCALA => Calle Avenida ALCALA
# CL-605 km 1 => CL-605 km 1
# CL FRAY JOSE DE SAN JACINTO 10 => Calle FRAY JOSE DE SAN JACINTO 10
# CL DR.MARAÑON C/V PL ESCORIAL, S.N. => Calle DR.MARAÑON C/V PL ESCORIAL, S.N.
# CL CALVARIO 10 => Calle CALVARIO 10
# CL BOULEVARD SALVADOR ALLENDE, 12-1 => Calle BOULEVARD SALVADOR ALLENDE, 12-1
# CL-601 (VALLADOLID-SEGOVIA) km 105 => CL-601 (VALLADOLID-SEGOVIA) km 105
# CL CARRETERA ARANJUEZ ,56 (CR M-305 (M-305 KM 19.8) => Calle Carretera ARANJUEZ ,56 (Carretera M-305 (M-305 KM 19.8)
# CL JARAMA (POLG. INDUST.PAR,22), S. => Calle JARAMA (POLG. INDUST.PAR,22), S.
# CL BARLOVENTO => Calle BARLOVENTO
# CL ALAMO, PL INDS LOS HUERTECILLO 49 (AV DE LA CONSTITUCION 167) => Calle ALAMO, PL INDS LOS HUERTECILLO 49 (Avenida DE LA CONSTITUCION 167)
# CL AVENIDA CASTILLA LA MANCHA, 79 (N-401 KM 35.5) => Calle Avenida CASTILLA LA MANCHA, 79 (N-401 KM 35.5)
# CL PASEO GALATEA, 35 (TO-423 KM 10.9) => Calle Paseo GALATEA, 35 (TO-423 KM 10.9)
# CL AVDA. S. MARTIN DE VALDEIGLE, S. (M-501 KM 0.3) => Calle Avenida S. MARTIN DE VALDEIGLE, S. (M-501 KM 0.3)
# CL FRANCISCO ARITIO  97 => Calle FRANCISCO ARITIO  97
# CL AV DE LA INDUSTRIA => Calle Avenida DE LA INDUSTRIA
# AVDA DEL VALLE 36 (CRTA M 604 KM 24.100) => Avenida DEL VALLE 36 (CRTA M 604 KM 24.100)
# AVDA DE MADRID => Avenida DE MADRID
# AVDA ARCAS DE AGUA SN => Avenida ARCAS DE AGUA SN
# AVDA. DEL ANTIGÜO FERROCARRIL, Nº 1 => Avenida DEL ANTIGÜO FERROCARRIL, Nº 1
# AVDA. ALTO DEL LEÓN, Nº 3 => Avenida ALTO DEL LEÓN, Nº 3
# AVDA. GENERALISIMO,12 => Avenida GENERALISIMO,12
# AVDA. SAN PABLO => Avenida SAN PABLO
# AVENIDA SAN PABLO => Avenida SAN PABLO
# AVENIDA PESETA => Avenida PESETA
# AVENIDA VALDELAPARRA (DE) => Avenida VALDELAPARRA (DE)
# AVENIDA AVDA. DE LA CABRERA S/N JUNTO AL HOSTAL EL CANCHO DEL AGUILA (A-1 KM 60), S/N => Avenida Avenida DE LA CABRERA S/N JUNTO AL HOSTAL EL CANCHO DEL AGUILA (A-1 KM 60), S/N
# AVENIDA TOLEDO => Avenida TOLEDO
# AVENIDA PORTUGAL (DE) => Avenida PORTUGAL (DE)
# AVENIDA ANDALUCIA => Avenida ANDALUCIA
# AVENIDA RIO GUADALQUIVIR => Avenida RIO GUADALQUIVIR
# AVENIDA LA INDUSTRIA, S/N => Avenida LA INDUSTRIA, S/N
# AVENIDA FUENTENUEVA => Avenida FUENTENUEVA
# AVENIDA DE LA CIRCUNVALACION => Avenida DE LA CIRCUNVALACION
# AVENIDA PORTUGAL (IZDO) => Avenida PORTUGAL (IZDO)
# AVENIDA HISPANIDAD => Avenida HISPANIDAD
# AVENIDA MADRID => Avenida MADRID
# AVENIDA AVDA DEL SOL ESQ.AVDA DE FRANCIA, SN => Avenida Avenida DEL SOL ESQ.Avenida DE FRANCIA, SN
# AVENIDA FUENLABRADA => Avenida FUENLABRADA
# AVENIDA CASTILLA LA MANCHA => Avenida CASTILLA LA MANCHA
# AVENIDA AURELIO ALVAREZ, S/N => Avenida AURELIO ALVAREZ, S/N
# AVENIDA EUROPA (C.C. LA MORALEJA), 13/15 => Avenida EUROPA (C.C. LA MORALEJA), 13/15
# AVENIDA QUITAPESARES => Avenida QUITAPESARES
# AVENIDA DE CASTILLA LA MANCHA 54 (TO-413 km 33) => Avenida DE CASTILLA LA MANCHA 54 (TO-413 km 33)
# AVENIDA RIO DUERO => Avenida RIO DUERO
# AVENIDA DE LA TECNICA, S/N => Avenida DE LA TECNICA, S/N
# AVENIDA CONSTITUCION => Avenida CONSTITUCION
# AV. CASTILLA => Avenida CASTILLA
# AUTOVIA E-901/A-3 KM 35.2 => Autovía E-901/A-3 KM 35.2
# AUTOVIA A-42 KM 57.700 => Autovía A-42 KM 57.700
# AUTOVIA A-3 KM 71.9 => Autovía A-3 KM 71.9
# AUTOVIA NACIONAL I KM 26.200 => Autovía NACIONAL I KM 26.200
# AUTOVIA A-3 KM 62.5 => Autovía A-3 KM 62.5
# AUTOVIA A-1 KM 29.1 => Autovía A-1 KM 29.1
# NACIONAL 320 km 276 => NACIONAL 320 km 276
# CAMINO SAN MARTIN CTRA. FONTANAR => CAMINO SAN MARTIN Carretera FONTANAR
# CAMINO DEL VENTORRILLO, S/N => CAMINO DEL VENTORRILLO, S/N
# N-400 KM 82.4 => N-400 KM 82.4
# N-II KM 29.000 => N-II KM 29.000
# CRTA. N-III PK. 41,00 => Carretera N-III PK. 41,00
# CRTA. N-I KM 14.5 => Carretera N-I KM 14.5
# A-4 KM 23.3 => A-4 KM 23.3
# A-5 => A-5
# CL.AGUILAS (P. IND. PINTO ESTACIÓN) => CL.AGUILAS (P. IND. PINTO ESTACIÓN)
# CTRA. N-IV km 32 => Carretera N-IV km 32
# CTRA. FUENLABRADA-HUMANES S/N => Carretera FUENLABRADA-HUMANES S/N
# CTRA. M-505 KM 5.5 => Carretera M-505 KM 5.5
# CTRA. N-I KM 64.650 => Carretera N-I KM 64.650
# CTRA. TOLEDO-BARGAS, KM 1.700 => Carretera TOLEDO-BARGAS, KM 1.700
# CTRA. N-V KM 12.5 => Carretera N-V KM 12.5
# CTRA. NACIONAL V, (el soto) KM 19.0 => Carretera NACIONAL V, (el soto) KM 19.0
# CTRA. 607 (DE COLMENAR A NAVACERRADA) KM 48.2 => Carretera 607 (DE COLMENAR A NAVACERRADA) KM 48.2
# CTRA. BURGOS => Carretera BURGOS
# CTRA. BOADILLA KM 1.0 => Carretera BOADILLA KM 1.0
# CTRA. VILLAVERDE-VALLECAS => Carretera VILLAVERDE-VALLECAS
# CTRA. MADRID TOLEDO km 10 => Carretera MADRID TOLEDO km 10
# CALLE CTRA. OCAÑA => Calle Carretera OCAÑA
# CALLE FRANCISCO MEDINA Y MENDOZA, P.4-18 => Calle FRANCISCO MEDINA Y MENDOZA, P.4-18
# CALLE JULIAN BESTEIRO, S/N => Calle JULIAN BESTEIRO, S/N
# CALLE EXTRAMUROS, S/N => Calle EXTRAMUROS, S/N
# CALLE FELIPE CALLEJA, S/N => Calle FELIPE CALLEJA, S/N
# CALLE GENERALISIMO => Calle GENERALISIMO
# CALLE NUEVA, S/N => Calle NUEVA, S/N
# CALLE HERNANDEZ TEJADA, S/N ESQ. AGASTIA, S/N (A-2 KM 5.1), S,N => Calle HERNANDEZ TEJADA, S/N ESQ. AGASTIA, S/N (A-2 KM 5.1), S,N
# CALLE NAVALPINO => Calle NAVALPINO
# CALLE REAL, S/N => Calle REAL, S/N
# CALLE CERRO SAN PEDRO => Calle CERRO SAN PEDRO
# CALLE NARCISO MONTURIOL => Calle NARCISO MONTURIOL
# CALLE ARAGON => Calle ARAGON
# CALLE DOCTOR CABAÑAS => Calle DOCTOR CABAÑAS
# CALLE PUENTE SAN ROQUE => Calle PUENTE SAN ROQUE
# CALLE COPENHAGUES/N, S/N => Calle COPENHAGUES/N, S/N
# CALLE FRANCISCO ARITIO, S/N => Calle FRANCISCO ARITIO, S/N
# CALLE I => Calle I
# CALLE EBANISTAS, => Calle EBANISTAS,
# CALLE CAMINO LEGANES => Calle CAMINO LEGANES
# CALLE CAMINO DE LA FABRICA, S/N => Calle CAMINO DE LA FABRICA, S/N
# CALLE INMACULADA => Calle INMACULADA
# CALLE CARRETERA SAN RAFAEL => Calle Carretera SAN RAFAEL
# CALLE CARDENAL GONZÁLEZ DE MENDOZA, S/N => Calle CARDENAL GONZÁLEZ DE MENDOZA, S/N
# CALLE SEGOVIA C/V A PASEO VIRGEN DEL PUERTO, S/N => Calle SEGOVIA C/V A Paseo VIRGEN DEL PUERTO, S/N
# CALLE ARTURO DUPERIER, S/N => Calle ARTURO DUPERIER, S/N
# CALLE CAMINO PORTASAGO, S/N => Calle CAMINO PORTASAGO, S/N
# CALLE SANTA MISION => Calle SANTA MISION
# CALLE ALCALA => Calle ALCALA
# CALLE PEDRO GARRIDO, S/N => Calle PEDRO GARRIDO, S/N
# CALLE SESEÑA => Calle SESEÑA
# CALLE LUIS SAUQUILLO => Calle LUIS SAUQUILLO
# M-832 => M-832
# M-100 => M-100
# M-40, PK 7.4 - ACCESO AL CAMPO DE LAS NACIONES => M-40, PK 7.4 - ACCESO AL CAMPO DE LAS NACIONES
# M-608 km 38 => M-608 km 38
# M-103 km 6.210 => M-103 km 6.210
# M-203 (MADRID-VICALVARO) km 3600 => M-203 (MADRID-VICALVARO) km 3600
# M-300 Carretera Alcalá-Loeches => M-300 Carretera Alcalá-Loeches
# M-103 km 6.207 => M-103 km 6.207
# M-208 KM 3.8 => M-208 KM 3.8
# M-603 (FUENCARRAL - ALCOBENDAS) KM 14.9 => M-603 (FUENCARRAL - ALCOBENDAS) KM 14.9
# M-505 KM 15.5 => M-505 KM 15.5
# C/ CTRA. ANDALUCÍA => Calle Carretera ANDALUCÍA
# C/. SAN PEDRO => Calle SAN PEDRO
# C/ San Joaquín nº5 => Calle San Joaquín nº5
# C/ Parque Grande => Calle Parque Grande
# C/ => C/
# C/ Sur => Calle Sur
# C/ Severo Ochoa => Calle Severo Ochoa
# C/ Don José Ingles => Calle Don José Ingles
# C/ Tiziano (Parque Urb. Felipe II ) => Calle Tiziano (Parque Urb. Felipe II )
# C/ José Bergamín => Calle José Bergamín
# C/ Arroyo Salcedo => Calle Arroyo Salcedo
# C/ CAMPEZO, 7 km CENTRO COMERCIAL M => Calle CAMPEZO, 7 km CENTRO COMERCIAL M
# C/Calderón Montero Ríos => C/Calderón Montero Ríos
# C/Las Pozas, s/n - P.I. Matacuervos => C/Las Pozas, s/n - P.I. Matacuervos
# Avda. del Pardo => Avenida del Pardo
# Avda. de la Paloma => Avenida de la Paloma
# Avda. de la Ilustración => Avenida de la Ilustración
# Avda. Juan Carlos I => Avenida Juan Carlos I
# Avda. Vicálvaro esq. Pobladura del Valle => Avenida Vicálvaro esq. Pobladura del Valle
# Avda. de los Arqueros => Avenida de los Arqueros
# Avda. de la Constitución => Avenida de la Constitución
# Avda. Madrid => Avenida Madrid
# Avda. Gran Bretaña => Avenida Gran Bretaña
# Avda. Covibar => Avenida Covibar
# AUTOP. VALENCIA KM 7.1 => Autopista VALENCIA KM 7.1
# CR.VILLALUENGA-COBEJA (TO-4512-V km P.K.2,0) => CR.VILLALUENGA-COBEJA (TO-4512-V km P.K.2,0)
# PASEO JUNCAREJO/CL DE AGORA => Paseo JUNCAREJO/Calle DE AGORA
# PASEO DE LA HERMITA DE STA. ANA => Paseo DE LA HERMITA DE STA. ANA
# PASEO DE LA ERMITA, S/N. => Paseo DE LA ERMITA, S/N.
# PASEO ESTACION, S/N => Paseo ESTACION, S/N
# POLIGONO CENTRO LOGISTICO DE ABASTECIMIENTO-PARCELA => Polígono CENTRO LOGISTICO DE ABASTECIMIENTO-PARCELA
# POLIGONO ALPARACHE, S/N => Polígono ALPARACHE, S/N
# POLIGONO FRANCISCO MEDINA Y MENDOZA PARCELA 10, S/N => Polígono FRANCISCO MEDINA Y MENDOZA PARCELA 10, S/N
# POLIGONO INDUSTRIAL BOADILLA PARCELAS 2-3-4, S/N => Polígono INDUSTRIAL BOADILLA PARCELAS 2-3-4, S/N
# POLIGONO LA CARBONERA, S/N => Polígono LA CARBONERA, S/N
# POLIGONO INDUSRIAL PINARES LLANOS, C/CARPINTEROS, S/N => Polígono INDUSRIAL PINARES LLANOS, C/CARPINTEROS, S/N
# CM-4009 km P.K.14,4 => CM-4009 km P.K.14,4
# CM-4003 => CM-4003
# CM-4001 km 23 => CM-4001 km 23
# CM-4003 km P.K.32,4 => CM-4003 km P.K.32,4
# CM-4001 => CM-4001
# SAN BERNARDO, S/N - Bº DE LA FORTUNA => SAN BERNARDO, S/N - Bº DE LA FORTUNA
# CERRO DE LA VEGA, S/N. => CERRO DE LA VEGA, S/N.
# POL. IND. VALDELASILLA - C.C. CAPRABO => Polígono IND. VALDELASILLA - C.C. CAPRABO
# GLORIETA LOS JAZMINES, S/N => GLORIETA LOS JAZMINES, S/N
# L-14 OCAÑA-PTE. PEDRERA KM 39.5 => L-14 OCAÑA-PTE. PEDRERA KM 39.5
# CC. LORANCA ALCAMPO FUENLABRADA (AV. PABLO IGLESIAS, S/N, CIUDAD LORANCA) => CC. LORANCA ALCAMPO FUENLABRADA (Avenida PABLO IGLESIAS, S/N, CIUDAD LORANCA)
# AV del Deporte => Avenida del Deporte
# AV DE MOSTOLES, Nº 6 => Avenida DE MOSTOLES, Nº 6
# C.N.-603-MARGEN DERECHO km 93.60000 => C.N.-603-MARGEN DERECHO km 93.60000
# C.N.-603-MARGEN IZQUIERDO km 93.60000 => C.N.-603-MARGEN IZQUIERDO km 93.60000
# C. C. LUZ DE CASTILLA - CTRA. DE SAN RAFAEL, N- 603 => C. C. LUZ DE CASTILLA - Carretera DE SAN RAFAEL, N- 603
# TO-4421-V km P.K.10,2 => TO-4421-V km P.K.10,2
# Callejón Eras => Callejón Eras
# Callejón de las Santas Formas => Callejón de las Santas Formas
# Callejón de Murcia => Callejón de Murcia
# Callejón del Alamillo => Callejón del Alamillo
# Callejón Gómez Acebo => Callejón Gómez Acebo
# Callejón Menores => Callejón Menores
# Callejón Tabernillas => Callejón Tabernillas
# Callejón Lucio => Callejón Lucio
# Callejón de Jorge Juan => Callejón de Jorge Juan
# Callejón de Ordóñez => Callejón de Ordóñez
# Callejón Vaquero => Callejón Vaquero
# Callejón de Gómez Acebo => Callejón de Gómez Acebo
# Callejón Cubillo de San Vicente => Callejón Cubillo de San Vicente
# Callejón del Mellizo => Callejón del Mellizo
# Callejón de San Ginés => Callejón de San Ginés
# Callejón de Juan de Mata Gómez => Callejón de Juan de Mata Gómez
# Callejón de la Luz => Callejón de la Luz
# Callejón Siete Chimeneas => Callejón Siete Chimeneas
# Callejón de Jesús => Callejón de Jesús
# Callejón de Preciados => Callejón de Preciados
# Callejón Dos Codos => Callejón Dos Codos
# Callejón de Ordoñez => Callejón de Ordoñez
# Callejón de Antequeruela => Callejón de Antequeruela
# Callejón de la Cruz => Callejón de la Cruz
# Callejón de García Cea => Callejón de García Cea
# Callejón Sillería => Callejón Sillería
# Callejón del Potro => Callejón del Potro
# Callejón del Chorrillo => Callejón del Chorrillo
# Callejón de la Concepción Jerónima => Callejón de la Concepción Jerónima
# Callejón del Arrabal del Hoyo => Callejón del Arrabal del Hoyo
# Callejón de la Huerta => Callejón de la Huerta
# Callejón del Molino => Callejón del Molino
# Alcocer, 23 => Alcocer, 23
# Vereda Gansino => Vereda Gansino
# Vereda del Altozano => Vereda del Altozano
# Vereda del Valle => Vereda del Valle
# Príncipe de Vergara => Príncipe de Vergara
# Dos Amigos => Dos Amigos
# Argumosa => Argumosa
# ZONA PLATAFORMA AEROPUERTO BARAJAS T123, S/N => ZONA PLATAFORMA AEROPUERTO BARAJAS T123, S/N
# ZONA AEROPUERTO DE BARAJAS, TERMINAL 2, S/N => ZONA AEROPUERTO DE BARAJAS, TERMINAL 2, S/N
# ZONA AEROPUERTO DE BARAJAS, T4, S/N => ZONA AEROPUERTO DE BARAJAS, T4, S/N
# DIAZ CORDOBES, S/N. => DIAZ CORDOBES, S/N.
# Avda de la Estación => Avenida de la Estación
# Avda de la Hispanidad 20 => Avenida de la Hispanidad 20
# Avda de Miguel Hernández => Avenida de Miguel Hernández
# Avda Valderremata s/n. => Avenida Valderremata s/n.
# Avda Juan Carlos I s/n, Parking exterior junto recogida de compras Alcampo => Avenida Juan Carlos I s/n, Parking exterior junto recogida de compras Alcampo
# CARRERA CARRETERA DE CRIÑON, S/N => CARRERA Carretera DE CRIÑON, S/N
# CARRERA VALENCIA, KM 14.800 => CARRERA VALENCIA, KM 14.800
# Ctra. de Extremadura => Carretera de Extremadura
# Ctra. De Algete, Km 1 (desvío Km. 23 de la N-1) San Sebastián de los Reyes => Carretera De Algete, Km 1 (desvío Km. 23 de la N-1) San Sebastián de los Reyes
# Ctra. Fuensalida - Torrijos => Carretera Fuensalida - Torrijos
# Ctra. de la Coruña => Carretera de la Coruña
# Ctra. N-601 => Carretera N-601
# Ctra. N-IV KM 55.200 => Carretera N-IV KM 55.200
# Ctra. Algete-Alalpardo => Carretera Algete-Alalpardo
# Ctra. de Robledo de Chabela => Carretera de Robledo de Chabela
# Ctra. de Bustarviejo, 26 => Carretera de Bustarviejo, 26
# Ctra. CL-601 Segovia a San Ildefonso => Carretera CL-601 Segovia a San Ildefonso
# Ctra. Piedrabuena => Carretera Piedrabuena
# Ctra. Villalba a Moralzarzal => Carretera Villalba a Moralzarzal
# Ctra.Moralzarzal => Ctra.Moralzarzal
# TR DEL DESVIO 19 => TR DEL DESVIO 19
# AUTOPISTA AUTOPISTA AP41 KM 31.760 => Autopista Autopista AP41 KM 31.760
# AUTOPISTA AUTOPISTA AP-41 KM 31.780 => Autopista Autopista AP-41 KM 31.780
# PLAZA MORALEJA S/N, S/N => PLAZA MORALEJA S/N, S/N
# PLAZA HUERTA DE LAS FLORES => PLAZA HUERTA DE LAS FLORES
# Castilla => Castilla
# Ciudad Jardín del Rosario => Ciudad Jardín del Rosario
# Hermandad de Donantes de Sangre => Hermandad de Donantes de Sangre
# Hermandad Donantes Sangre => Hermandad Donantes Sangre
# España => España
# Fuenlabrada => Fuenlabrada
# Proción => Proción
# ROSA DE LIMA => ROSA DE LIMA
# Maria de Molina => Maria de Molina
# Pintor Rivera, 1 posterior => Pintor Rivera, 1 posterior
# Pintor Murillo => Pintor Murillo
# Pintor Velazquez => Pintor Velazquez
# Sor Juana Inés de la Cruz => Sor Juana Inés de la Cruz
# Sor Livia Alcorta => Sor Livia Alcorta
# Call de la Hermandad de Donantes Sangre => Calle de la Hermandad de Donantes Sangre
# Profesor Waksman 6 => Profesor Waksman 6
# Profesor Waksman, 5 => Profesor Waksman, 5
# Espinar 1 => Espinar 1
# ladera del chorrillo => ladera del chorrillo
# Santander => Santander
# Albala => Albala
# Miguel de Cervantes => Miguel de Cervantes
# Miguel Ángel => Miguel Ángel
# Santa Engracia => Santa Engracia
# Santa Isabel => Santa Isabel
# Federico Moreno Torroba => Federico Moreno Torroba
# Federico Salmón => Federico Salmón
# Quitapesares => Quitapesares
# Reina Sofía => Reina Sofía
# Marmolistas => Marmolistas
# Turín => Turín
# Lisboa => Lisboa
# Madrid => Madrid
# Ctra del Pardo => Carretera del Pardo
# Ctra Las Rozas - El Escorial => Carretera Las Rozas - El Escorial
# Ctra de la Granja => Carretera de la Granja
# Cataluña => Cataluña
# Venezuela => Venezuela
# Cuzco => Cuzco
# Rotonda de Pitágoras => Rotonda de Pitágoras
# Valderromán => Valderromán
# Pamplona => Pamplona
# General Ibáñez de Ibero => General Ibáñez de Ibero
# General Ricardos, 175 => General Ricardos, 175
# General Lacy => General Lacy
# General Ricardos => General Ricardos
# General Aranaz => General Aranaz
# General Asensio Cabanillas => General Asensio Cabanillas
# Francisco Ayala, 1 => Francisco Ayala, 1
# Francisco Javier Sauquillo => Francisco Javier Sauquillo
# 11 Posterior => 11 Posterior
# Salvador Sanchez Frascuelo => Salvador Sanchez Frascuelo
# Via de las dos Castillas => Vía de las dos Castillas
# Via de Servicio, 19 => Vía de Servicio, 19
# Via De Los Poblados => Vía De Los Poblados
# Via de las Dos Castillas => Vía de las Dos Castillas
# Calvario => Calvario
# Camilo José Cela => Camilo José Cela
# Camilo Jose Cela => Camilo Jose Cela
# Puerta del Sol => Puerta del Sol
# Puerta del Cambrón => Puerta del Cambrón
# Puerta de Abajo => Puerta de Abajo
# Real => Real
# Casas de Miravete => Casas de Miravete
# Ribera de Curtidores => Ribera de Curtidores
# Pedro Gumiel => Pedro Gumiel
# Pedro de Valdivia => Pedro de Valdivia
# Lope de Vega => Lope de Vega
# Comunidad de Madrid => Comunidad de Madrid
# Oslo => Oslo
# Bruselas => Bruselas
# Martin Iriarte => Martin Iriarte
# Honduras => Honduras
# Juan Ramon Jimenez => Juan Ramon Jimenez
# Juan Guerra => Juan Guerra
# Juan Alvarez Mendizaba => Juan Alvarez Mendizaba
# Juan de Toledo => Juan de Toledo
# Chiapas => Chiapas
# Kalamos => Kalamos
# San Vidal => San Vidal
# San Cipriano => San Cipriano
# San Agustin => San Agustin
# San Andrés => San Andrés
# Cabo Estaca de Bares => Cabo Estaca de Bares
# Cabo Rufino Lázaro => Cabo Rufino Lázaro
# Lina de Avila => Lina de Avila
# Matacerquillas => Matacerquillas
# Fontanilla => Fontanilla
# Pza. Epifanio Velasco => Plaza Epifanio Velasco
# Castiello De Jaca => Castiello De Jaca
# Carrterera de El Plantío => Carrterera de El Plantío
# Acacias => Acacias
# Amor de Dios => Amor de Dios
# Tunel O'Donnell => Tunel O'Donnell
# Cava de San Miguel => Cava de San Miguel
# Teniente Ruiz => Teniente Ruiz
# Serrano => Serrano
# crta de Galapagar a Villalba M-528 => Carretera de Galapagar a Villalba M-528
# Sector Literatos 3. => Sector Literatos 3.
# Sector Músicos => Sector Músicos
# Sector Fray José de Almonacid => Sector Fray José de Almonacid
# Sector Caraquiz => Sector Caraquiz
# Topete => Topete
# Valparaíso => Valparaíso
# Eric Kandel => Eric Kandel
# Callejuela de la Clínica => Callejuela de la Clínica
# Virgen del Sagrario => Virgen del Sagrario
# Virgen de la Alegría => Virgen de la Alegría
# Virgen del Canto => Virgen del Canto
# Virgen del Coro => Virgen del Coro
# Virgen de Nuria => Virgen de Nuria
# Virgen del Pilar => Virgen del Pilar
# Virgen del Amparo => Virgen del Amparo
# Virgen de la Providencia => Virgen de la Providencia
# Virgen de la Hoz => Virgen de la Hoz
# Batalla del Salado => Batalla del Salado
# Pz. Sta Mª de la Cabeza => Plaza Sta Mª de la Cabeza
# Paloma => Paloma
# Travesia Colombia => Travesía Colombia
# Travesia Conde Duque => Travesía Conde Duque
# Travesia Calle Ancha => Travesía Calle Ancha
# Travesia Paloma => Travesía Paloma
# Travesia de la Comadre => Travesía de la Comadre
# Travesia Bravo Murillo => Travesía Bravo Murillo
# Amparo => Amparo
# Tarragona => Tarragona
# Calleja/Callejï¿½ï¿½n Viento => Calleja/Callejï¿½ï¿½n Viento
# Calleja A => Calleja A
# Calleja/Callejï¿½ï¿½n Tabernillas => Calleja/Callejï¿½ï¿½n Tabernillas
# Calleja del Potro  => Calleja del Potro
# Calleja/Callejï¿½ï¿½n Callejon-alpedrete => Calleja/Callejï¿½ï¿½n Callejon-alpedrete
# Calleja del Potro => Calleja del Potro
# Calleja de Cavanilles => Calleja de Cavanilles
# Travesï¿½ï¿½a Alta-alpedrete => Travesï¿½ï¿½a Alta-alpedrete
# Travesï¿½ï¿½a Santiago => Travesï¿½ï¿½a Santiago
# Travesï¿½ï¿½a Travesia A => Travesï¿½ï¿½a Travesía A
# Conde Duque => Conde Duque
# Mayor => Mayor
# Divino Pastor (entrada por San Andrés) => Divino Pastor (entrada por San Andrés)
# Plaseo de las Acacias => Paseo de las Acacias
# Yeros => Yeros
# Pretil de Santiesteban => Pretil de Santiesteban
# calle Dulcinea del Toboso => Calle Dulcinea del Toboso
# calle De los Alamillos, 13. Toledo => Calle De los Alamillos, 13. Toledo
# calle de Benito Monfort => Calle de Benito Monfort
# calle Mayor => Calle Mayor
# calle de los Alamillos  => Calle de los Alamillos
# calle de la Pintora Ángeles Santos => Calle de la Pintora Ángeles Santos
# calle Tokio => Calle Tokio
# Crta. de Ugena => Carretera de Ugena
# Crta. M600 De Valdemorillo a El Escorial => Carretera M600 De Valdemorillo a El Escorial
# Mercado de Barceló => Mercado de Barceló
# Palos de la Frontera => Palos de la Frontera
# La Mequera => La Mequera
# La Torre => La Torre
# La Venta => La Venta
# plaza de Manuel Marchamalo => Plaza de Manuel Marchamalo
# plaza de Castilla => Plaza de Castilla
# plaza Tingo Maria 12 => Plaza Tingo Maria 12
# Gobernador Fernández Jiménez => Gobernador Fernández Jiménez
# IES Sapere Aude => IES Sapere Aude
# Auditorio Sebastián Cesteros => Auditorio Sebastián Cesteros
# Pista multijuegos => Pista multijuegos
# Pista Cristo del Pardo => Pista Cristo del Pardo
# Grecia => Grecia
# Tenerife => Tenerife
# Almíbar => Almíbar
# Pinos Alta => Pinos Alta
# María Tubau => María Tubau
# Gavilán
#  => Gavilán
#
# Leopoldo Alas "Clarín" => Leopoldo Alas "Clarín"
# Albert Amon => Albert Amon
# Pasage de Matheu => Pasaje de Matheu
# FIXME Paseo San Francisco De Sales => FIXME Paseo San Francisco De Sales
# FIXME Avenida La Verbena De La Paloma => FIXME Avenida La Verbena De La Paloma
# FIXME FUENTE DEL BERRO, CALLE, DE LA => FIXME FUENTE DEL BERRO, CALLE, DE LA
# FIXME IBIZA, CALLE, DE => FIXME IBIZA, CALLE, DE
# Narciso Monturiol => Narciso Monturiol
# JAEN => JAEN
# Avenidad de las Arcas del Agua => Avenida de las Arcas del Agua
# Crta 607 => Carretera 607
# Oña => Oña
# Corral de la Sinagoga => Corral de la Sinagoga
# Urb. Bellavista => Urb. Bellavista
# Urb. Los LLanos => Urb. Los LLanos
# Urb. Pryconsa => Urb. Pryconsa
# Urb. ParqueSierra => Urb. ParqueSierra
# Isla de Lobeira => Isla de Lobeira
# Isla Graciosa => Isla Graciosa
# Urbanización Semisierra => Urbanización Semisierra
# Urbanización Princialba => Urbanización Princialba
# Urbanización Venecia => Urbanización Venecia
# Urbanización Gran Hábitat => Urbanización Gran Hábitat
# Urbanización Tres Culturas => Urbanización Tres Culturas
# Urbanización Santos Niños => Urbanización Santos Niños
# Urbanización Nuevo Versalles => Urbanización Nuevo Versalles
# Urbanización Noria de la Paz => Urbanización Noria de la Paz
# Urbanización Villalba 20 => Urbanización Villalba 20
# Urbanización Montenebros II => Urbanización Montenebros II
# Urbanización Montenebros I => Urbanización Montenebros I
# Urbanización Los Enebros => Urbanización Los Enebros
# Urbanización Casablanca => Urbanización Casablanca
# Jacinto Verdaguer => Jacinto Verdaguer
# Fornells => Fornells
# Constitución => Constitución
# Gerardo Diego => Gerardo Diego
# Amnistía => Amnistía
# Alfonso XII => Alfonso XII
# Concejo/Colegio Ejercito de Tierra => Concejo/Colegio Ejercito de Tierra
# Polï¿½ï¿½gono Vpv.016.pt.ciudad Ocio => Polï¿½ï¿½gono Vpv.016.pt.ciudad Ocio
# Polï¿½ï¿½gono Vp Arpo => Polï¿½ï¿½gono Vp Arpo
# Alegría de Oria => Alegría de Oria
# Cañada de San Marcos => Cañada de San Marcos
# Cañada Real Galiana => Cañada Real Galiana
# Cañada => Cañada
# Condesa del Venadito => Condesa del Venadito
# Bordadores => Bordadores
# Guzmán el Bueno => Guzmán el Bueno
# Rafaela Aparicio => Rafaela Aparicio
# Rafaela Ybarra => Rafaela Ybarra
# Rosario Romero => Rosario Romero
# Avd. Juan Carlos I => Avenida Juan Carlos I
# Carre de las Moreras => Carre de las Moreras
# Campus de Somosagua, Ctra. de Húmera, s/n, Pozuelo de Alarcón, Madrid => Campus de Somosagua, Carretera de Húmera, s/n, Pozuelo de Alarcón, Madrid
# Vale de Eusebio Blasco => Vale de Eusebio Blasco
# Eugenio Sellés => Eugenio Sellés
# Fabián Lorente => Fabián Lorente
# del Ferrocarril => del Ferrocarril
# Matadero => Matadero
# Circunvalación (Posterior) => Circunvalación (Posterior)
# Centro Comercial Getafe 3 => Centro Comercial Getafe 3
# Van Gogh => Van Gogh
# Los Frailes => Los Frailes
# Los Ánegles => Los Ánegles
# Los Lecheros => Los Lecheros
# Zurbarán  => Zurbarán
# Rufino González => Rufino González
# Motilla del Palancar => Motilla del Palancar
# Silvano => Silvano
# Bucarmanga => Bucarmanga
# Cristo del Pardo => Cristo del Pardo
# El Pardo a Colmenar Viejo => El Pardo a Colmenar Viejo
# Londres => Londres
# zarzuela => zarzuela
# Verdad => Verdad
# Pico de la cierva => Pico de la cierva
# Herencia => Herencia
# Violeta => Violeta
# Orquídea => Orquídea
# Embajadores => Embajadores
# Acceso Parque de la Elipa => Acceso Parque de la Elipa
# Acceso a la Colonia Marconi => Acceso a la Colonia Marconi
# Pez Austral => Pez Austral
# Crisalida => Crisalida
# Palazuelos de Eresma => Palazuelos de Eresma
# Zerynthia => Zerynthia
# Coscinia => Coscinia
# Saturnia => Saturnia
# Paraje Pontezuela => Paraje Pontezuela
# Paraje de la Dehesa => Paraje de la Dehesa
# Alexander Graham Bell => Alexander Graham Bell
# Samaniego => Samaniego
# Concilios de Toledo => Concilios de Toledo
# Septiembre => Septiembre
# Fermín Caballero => Fermín Caballero
# Aguacate => Aguacate
# Fundidores => Fundidores
# Faraday => Faraday
# Marie Curie => Marie Curie
# Severo Ochoa => Severo Ochoa
# Rector Royo Villanova => Rector Royo Villanova
# Alonso Cano => Alonso Cano
# Palmera => Palmera
# Río Tormes => Río Tormes
# Charco => Charco
# Pizarro => Pizarro
# Ginebra => Ginebra
# Viena => Viena
# Veredilla => Veredilla
# Pío Baroja => Pío Baroja
# Valderrey => Valderrey
# Aragón => Aragón
# Brasil, 4 => Brasil, 4
# Brasil, 6 => Brasil, 6
# Victoria Kent => Victoria Kent
# Luis Sauquillo => Luis Sauquillo
# Luis de Medina => Luis de Medina
# Finca Tirabuey => Finca Tirabuey
# Princesa de Éboli => Princesa de Éboli
# López de Hoyos => López de Hoyos
# Cid Campeador => Cid Campeador
# Federica Montseny => Federica Montseny
# Comandante Fontanes => Comandante Fontanes
# Estrella Polar => Estrella Polar
# Recodo del Pinar => Recodo del Pinar
# Ventura Rodríguez => Ventura Rodríguez
# Rcda Carrasquilla => Rcda Carrasquilla
# Rcda Bernaldo de Quirós => Rcda Bernaldo de Quirós
# Rcda San Francisco => Rcda San Francisco
# Carmen Martín Gaite => Carmen Martín Gaite
# Daoiz y Velarde => Daoiz y Velarde
# Viario de Ronda => Viario de Ronda
# callejón del Clavel => callejón del Clavel
# Prolongación Calle de Jorge Guillén => Prolongación Calle de Jorge Guillén
# Joaquín Turina => Joaquín Turina
# Sierra Morena => Sierra Morena
# Néctar => Néctar
# Cardenal Cisneros => Cardenal Cisneros
# Elfo => Elfo
# Sambara => Sambara
# Emilio Gastesi Fernández => Emilio Gastesi Fernández
# Travesïa Primer => Travesïa Primer
# Antonio Buero Vallejo => Antonio Buero Vallejo
# Antonio Van de Pere => Antonio Van de Pere
# Disem de Colmenar de Oñoro => Disem de Colmenar de Oñoro
# Rinconada de Juan del Campo => Rinconada de Juan del Campo
# Rinconada de la Estrella => Rinconada de la Estrella
# Rinconada Magdalena => Rinconada Magdalena
# Salida de San Andrés => Salida de San Andrés
# Fernando de Rojas => Fernando de Rojas
# Aguado => Aguado
# Lilí Álvarez => Lilí Álvarez
# Entrada a la Sala de Exposiciones => Entrada a la Sala de Exposiciones
# Huesca => Huesca
# Pz San Antonio de la Florida => Plaza San Antonio de la Florida
# Montamarta => Montamarta
# Pobladura del Valle => Pobladura del Valle
# Diseminados Pingarron => Diseminados Pingarron
# Diseminados Diseminados => Diseminados Diseminados
# Diseminados Ds.resto Municipio => Diseminados Ds.resto Municipio
# Martínez Villergas => Martínez Villergas
# Avd Conde de Romanones => Avenida Conde de Romanones
# Musgo => Musgo
# pitano => pitano
# uvas => uvas
# encinas => encinas
# espinos => espinos
# Taray => Taray
# Mariano Saiz => Mariano Saiz
# Telecomunicaciones => Telecomunicaciones
# Antigua Carretera de Barcelona Km. => Antigua Carretera de Barcelona Km.
# Estocolmo => Estocolmo
# Padrón => Padrón
# Talleres mecánicos González => Talleres mecánicos González

# %%
data.process_map(sample_file, validate = False)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-12-60d4b855635e> in <module>()
# ----> 1 data.process_map(sample_file, validate = False)
#
# C:\Users\Serg\Documents\Aprendiendo\Data Analysis\Module 4 - Data Wrangling\Project - Open Street Map\data.py in process_map(file_in, validate)
#     330                 if element.tag == 'node':
#     331                     nodes_writer.writerow(el['node'])
# --> 332                     node_tags_writer.writerows(el['node_tags'])
#     333                 elif element.tag == 'way':
#     334                     ways_writer.writerow(el['way'])
#
# C:\Users\Serg\Documents\Aprendiendo\Data Analysis\Module 4 - Data Wrangling\Project - Open Street Map\data.py in writerows(self, rows)
#     293     def writerows(self, rows):
#     294         for row in rows:
# --> 295             self.writerow(row)
#     296
#     297
#
# C:\Users\Serg\Documents\Aprendiendo\Data Analysis\Module 4 - Data Wrangling\Project - Open Street Map\data.py in writerow(self, row)
#     288     def writerow(self, row):
#     289         super(UnicodeDictWriter, self).writerow({
# --> 290             k: (v.encode('utf-8') if isinstance(v, str) else v) for k, v in row.items()
#     291         })
#     292
#
# C:\Users\Serg\Anaconda3\envs\py2\lib\csv.pyc in writerow(self, rowdict)
#     150
#     151     def writerow(self, rowdict):
# --> 152         return self.writer.writerow(self._dict_to_list(rowdict))
#     153
#     154     def writerows(self, rowdicts):
#
# UnicodeEncodeError: 'ascii' codec can't encode characters in position 0-4: ordinal not in range(128)

# %%
db = sqlite.connect("osm_madrid")
c = db.cursor()
query = "CREATE TABLE nodes (id INTEGER PRIMARY KEY NOT NULL,lat REAL,lon REAL,user TEXT,uid INTEGER,version INTEGER,changeset INTEGER,timestamp TEXT);"
c.execute(query)
rows = c.fetchall()
db.close()

# %%
db = sqlite.connect("osm_madrid")
c = db.cursor()
query = ".schema"
c.execute(query)
rows = c.fetchall()
db.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-a78971cab3f2> in <module>()
#       2 c = db.cursor()
#       3 query = ".schema"
# ----> 4 c.execute(query)
#       5 rows = c.fetchall()
#       6 db.close()
#
# OperationalError: near ".": syntax error

# %%
# counting phone entries in 'nodes' 'tags'
t0 = time()
counter = 0 
for event, element in ET.iterparse(sample_file):
    if element.tag == 'node':
        for tag in element.iter('tag'):
            if tag.attrib['k'] == 'phone' or tag.attrib['k'] == 'contact:phone':
                counter += 1
print(time() - t0)
print(counter)
# Out:
# 0.005881547927856445
# 1

# %%
# counting phone entries in 'nodes' 'tags'
t0 = time()
counter = 0 
for event, element in ET.iterparse(sample_file):
    if element.tag == 'tag':
        for tag in element.iter('tag'):
            if tag.attrib['k'] == 'phone' or tag.attrib['k'] == 'contact:phone':
                counter += 1
print(time() - t0)
print(counter)
# Out:
# 0.007307291030883789
# 1

# %%
# Audit tag key string types
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == "tag":
        k_value = element.attrib['k']
        if lower.search(k_value):
            keys['lower'] += 1
        elif lower_colon.search(k_value):
            keys['lower_colon'] += 1
        elif problemchars.search(k_value):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
t0= time()
print(process_map(sample_file))
print(time() - t0)
# Out:
# {'lower': 183, 'lower_colon': 101, 'problemchars': 0, 'other': 5}
# 0.007745981216430664

# %%
# Extract unique user ids
def get_user(element):
    if element.tag == 'way' or element.tag == 'node':
        if 'uid' in element.attrib.keys():
            uid = element.attrib['uid']
        else:
            uid = 'uid_absent'
    else:
        uid = None
    return uid 


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if get_user(element):
            users.add(get_user(element))
    return users

# %%
t0= time()
user_id = process_map(sample_file)
print(len(user_id))
print(time() - t0)
# Out:
# 123
# 0.008822917938232422

# %%
print('type:', type(user_id))
print('length:', len(user_id))
missing_uids = 0
index_list = []
for i in user_id:
    if i == 'uid_absent':
        missing_uids += 1
        index_list.append('uid_missing')
    else:
        index_list.append('uid_present')
print('missing uids:', missing_uids)
#print 'missing uid index', index_list.index('uid_missing')
# Out:
# type: <class 'set'>
# length: 123
# missing uids: 0

# %%
# Extract unique user names# Extrac 
def get_user(element):
    if element.tag == 'way' or element.tag == 'node':
        if 'user' in element.attrib.keys():
            user = element.attrib['user']
        else:
            user = 'user_name_absent'
    else:
        user = None
    return user

def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if get_user(element):
            users.add(get_user(element))
    return users

# %%
t0= time()
user_name = process_map(sample_file)
print(user_name)
print(len(user_name))
print(type(user_name))
print(time()-t0)
# Out:
# {'Luiyo', 'Pelanas', 'Sabiki', 'Mateño', 'scambelo', 'JeLuF', 'valdenebro', 'nicole_germany', 'Diego Esteban Alonso Blas', 'BCNorwich', 'Steeley', 'Marion_Moseby', 'dardhal', 'Hispadat', 'mojitopt', 'polkillas', 'Aaco', 'Urii_67', 'Pluvium', 'jorvime', 'jamesks', 'Polyglot', 'davidd95', 'jrgamo', 'Sercontr', 'FrViPofm', 'alcatoo', 'Antonio Garzón', 'Angel Fernandez', 'ANewTolay', 'flierfy', 'rafaerti', 'Habbit', 'c4rodriguez', 'carlosz22', 'sanchi', 'Marcsinnick', 'jcsogo', 'Pozuelo de Alarcon', 'R2ree2', 'Latze', 'NachoBlanco', 'Feuerfluss', 'Eduarson26', 'jespa', 'Cresques', 'lesp78', 'cronoser', 'C-SIm', 'gpesquero', 'VOST Madrid', 'intercacia', 'wingmaster', 'FahRadler', 'yabanci', 'Takeoff', 'Importación catastro de Sevilla la Nueva (Madrid)', 'antecessor', 'felixi', 'dvidrie', 'Anonxak', 'CarlosMG', 'Imp_GL', 'MorenoAraujo', 'robertogeb', 'Jesús Gómez', 'oscarorbe', 'cirdancarpintero', 'Graeme Herbert', 'JavierSp', 'Davpalnan', '_Reppu_', 'Canellone', 'Serfuen', 'x0c0', 'c_gonzalez', 'alcazar', 'Tronikon', 'ftprinc', 'MarcelHerault', 'shgmap', 'yayoyuuwill', 'angelidito', 'jgallegocuesta', 'Soymano', 'antonio moratilla', 'Zartbitter', 'lingg', 'xavi5', 'jaiser', 'ElTitoGabi', 'ManoloL', 'MrPart', 'bivente', 'balrog-kun', 'Heavenlyaviator', 'Quique456', 'Roberpl', 'DaveFX', 'M Angel', 'ansuta', 'Xiaqi', 'Ropino', 'chdr', 'migonso', 'ambmapper', 'C-P-M', 'OpenSourceForEver', 'oretano', 'Remiguel', 'natius', 'rubensd', 'chillfmm', 'Javi-biker', 'Cuenqui', 'KozHub', 'JMSB113', 'Raul Gonzalez', 'radnaj', 'duduvk', 'sergionaranja', 'Iván_', 'mor'}
# 123
# <class 'set'>
# 0.011192798614501953

# %%
sorted(lowers)
# Out:
# ['access',
#  'amenity',
#  'barrier',
#  'bench',
#  'bridge',
#  'building',
#  'bus',
#  'created_by',
#  'crossing',
#  'cuisine',
#  'destination',
#  'emergency',
#  'entrance',
#  'height',
#  'hgv',
#  'highway',
#  'int_ref',
#  'is_in',
#  'landuse',
#  'lanes',
#  'layer',
#  'leisure',
#  'maxspeed',
#  'motorroad',
#  'name',
#  'natural',
#  'noexit',
#  'note',
#  'oneway',
#  'opening_hours',
#  'operator',
#  'parking',
#  'place',
#  'power',
#  'public_transport',
#  'ref',
#  'service',
#  'shelter',
#  'shop',
#  'smoking',
#  'source',
#  'surface',
#  'tourism',
#  'type',
#  'waterway',
#  'wheelchair']

# %%
sorted(lowers_colon)
# Out:
# ['addr:city',
#  'addr:country',
#  'addr:district',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'building:levels',
#  'contact:email',
#  'contact:phone',
#  'contact:website',
#  'educamadrid:bilingue',
#  'educamadrid:cod_centro',
#  'educamadrid:codigo_postal',
#  'educamadrid:comedor',
#  'educamadrid:distrito',
#  'educamadrid:fax',
#  'educamadrid:horario_amp',
#  'educamadrid:municipio',
#  'educamadrid:nombre_via',
#  'educamadrid:numero_portal',
#  'educamadrid:publico_bilingue',
#  'educamadrid:telefono',
#  'educamadrid:tipo',
#  'educamadrid:tipo_via',
#  'educamadrid:transporte',
#  'educamadrid:url',
#  'fire_hydrant:type',
#  'is_in:state',
#  'is_in:state_code',
#  'ngbe:codigo',
#  'ngbe:grupo',
#  'ngbe:huso',
#  'ngbe:id',
#  'ngbe:subgrupo',
#  'ngbe:tema',
#  'ngbe:tipotexto',
#  'ngbe:version',
#  'note:es',
#  'ref:colour',
#  'ref:colour_bg',
#  'source:date',
#  'source:file',
#  'source:name',
#  'source:url']

# %%
sorted(others)
# Out:
# ['ngbe:hojabcn25',
#  'ngbe:lat_ed50',
#  'ngbe:lon_ed50',
#  'ngbe:xutm_ed50',
#  'ngbe:yutm_ed50']

# %%
# Find values listed under 'addr:street:en' and 'addr:street_1'
t0 = time()
streets_under_alt_k = []
for _, element in ET.iterparse(sample_file):
    if element.tag == 'tag':
        if element.attrib['k'] == 'addr:street:en' or element.attrib['k'] == 'addr:street_1':
            streets_under_alt_k.append(element.attrib['v'])
for i in streets_under_alt_k:
    print(i)

# %% [markdown]
# ## ENTENDER

# %%
'''Auditing phone numbers'''
'''def audit_phone_number(phone_number)'''

#regex_normal = re.compile(r'(\+?38)?\W*(0?\W*\d{2})?\W*(\d\W*\d\W*\d)\W*(\d{2})\W*(\d{2})')
#regex_normal = re.compile(r'(\+?38)?\W*(0?\d{2})?\W*(\d\d\d)\W*(\d{2})\W*(\d{2})')
#regex_normal = re.compile(r'(38)?\W*(0)?\W*(\d{2})?\W*(\d{3})\W*(\d{2})\W*(\d{2})')
#regex_38 = re.compile(r'(\+?)(38)\W*(0)\W*(\d{2})\W*(\d{3})\W*(\d{2})\W*(\d{2})')
regex_38 = re.compile(r'(3)\W*(8)\W*(0)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\b')
#regex_0xx = re.compile(r'^\W?(0\d{2})\W*(\d{3})\W*(\d{2})\W*(\d{2})\b')
regex_0xx = re.compile(r'^\W?(0)\W*(\d{2})\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\b')
#regex_800 = re.compile(r'\d\W800\W\d{3}\W\d{3}')
regex_800 = re.compile(r'^(0|8)\W*(800)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\b')
regex_xxx = re.compile(r'^(\d{3})\W*(\d{2})\W*(\d{2})$')

# %%
ph = r'0800500-609'
m = regex_800.findall(ph)
m
# Out:
# [('0', '800', '5', '0', '0', '6', '0', '9')]

# %%
# Count regex matches 
t0 = time()
counter = {'w38':0, 'w800':0, 'w0xx':0, 'wxxx':0, 'problematic':0}
w38 = []
w800 = []
w0xx = []
wxxx = []
problematics = []
for event, elem in ET.iterparse(sample_file):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib['k'] == "phone" or tag.attrib['k'] == "contact:phone":
                if regex_38.search(tag.attrib['v']):
                    counter['w38'] += 1
                    w38.append(tag.attrib['v'])
                elif regex_800.search(tag.attrib['v']):
                    counter['w800'] += 1
                    w800.append(tag.attrib['v'])
                elif regex_0xx.search(tag.attrib['v']):
                    counter['w0xx'] += 1
                    w0xx.append(tag.attrib['v'])
                elif regex_xxx.search(tag.attrib['v']):
                    counter['wxxx'] += 1
                    wxxx.append(tag.attrib['v'])
                else:
                    counter['problematic'] += 1
                    problematics.append(tag.attrib['v'])
print(time() - t0)
print(counter)
# Out:
# 0.0059735774993896484
# {'w38': 0, 'w800': 0, 'w0xx': 0, 'wxxx': 0, 'problematic': 1}

# %%
sorted(problematics)
# Out:
# ['+34 915424131']

# %%
phone_mapping = {
    '(44)4247431' : '+38-044-424-7431',
     '+1 347 868 0740' : '+1-347-868-0740', 
     '+3-044-257-20-97' : '+38-044-257-2097',
     '+3-8-044-446-77e-70' : '+38-044-446-7770',
     '+30 (44) 536-99-06; +30 (44) 536-99-08; +30 (44) 536-99-07' : '+38-044-536-9906', 
     '+3044 401-42-94' : '+38-044-401-4294',
     '+30442556013' : '+38-044-255-6013', 
     '+38 44 2784864' : '+38-044-278-4864', 
     '+38 44 425 03 98' : '+38-044-4250-0398', 
     '+380 (044) 235-73-82' : '+38-044-235-7382', 
     '+380 (044) 275-33-00' : '+38-044-275-3300', 
     '+380 (044) 360 02 09' : '+38-044-360 0209', 
     '+380 (044) 486-18-08' : '+38-044-486-1808', 
     '+380 (067) 912-20-66' : '+38 067 912-2066', 
     '+380 44 01010' : 'ERRONEUS', 
     '+380 9905577327' : '+38-099-055-77327', 
     '+380(044) 528-30-47' : '+38-044-528-3047',
     '+380-044-4172526' : '+38-044-417-2526', 
     '+3800675055958' : '+38-067-505-5958', 
     '+3804118875' : 'ERRONEOUS', 
     '+38986073213' : '+38-098-607-3213',
     '+39 044 5939575' : '+38-044-593-9575',
     '+800 1800 1800' : 'ERRONEUOUS', 
     '044526' : 'ERRONEOUS', 
     '08005005000' : 'ERRONEOUS', 
     '102' : ' ERRONEOUS', 
     '234-55-83;234-05-88;235-23-21' : '+38-044-234-5583', 
     '287-32-11 066-563-57-29' : '38-044-287-3211', 
     '2870711,2870020' : '+38-044-287-0711', 
     '2876149,2876216' : '+38-044-287-6149', 
     '4-60-85' : 'ERRONEOUS', 
     '5-74-41' : 'ERRONEOUS',
     '67 401 21 66, 044 287 5252' : '+38-067-401-2166', 
     '8097-331-17-93' : '+38-097-331-1793', 
     '88003000500' : 'ERRONEOUS', 
 u'\u0420\u0435\u0433\u0438\u0441\u0442\u0440\u0430\u0442\u0443\u0440\u0430 - (044) 408-03-41, \u0412\u044b\u0437\u043e\u0432 \u0432\u0440\u0430\u0447\u0430 - (044) 408-74-40, \u041d\u0435\u043e\u0442\u043b\u043e\u0436\u043d\u0430\u044f \u043f\u043e\u043c\u043e\u0449\u044c - (044) 497-60-61'
: '38-044-408-0341'}

# %%
# Define function to standardize phone numbers
def standardize_phone(number, phone_mapping):
    stnd = ''
    if regex_38.search(number):
        m = regex_38.search(number)
        stnd = stnd + '+' + m.group(1) + m.group(2) + '-' + m.group(3) + m.group(4) + m.group(5) + '-' + m.group(6) + \
                m.group(7) + m.group(8) + '-' + m.group(9) + m.group(10) + m.group(11) + m.group(12)
    elif regex_800.search(number):
        m = regex_800.search(number)
        stnd = stnd + m.group(1) + '-' + m.group(2) + '-' + m.group(3) + m.group(4) + m.group(5) + '-' + m.group(6) + \
                m.group(7) + m.group(8)
    elif regex_0xx.search(number):
        m = regex_0xx.search(number)
        stnd = stnd + '+38-' + m.group(1) + m.group(2) + '-' + m.group(3) + m.group(4) + m.group(5) + '-' + m.group(6) + \
                m.group(7) + m.group(8) + m.group(9) 
    elif regex_xxx.search(number):
        m = regex_xxx.search(number)
        stnd = stnd + '+38-044-' + m.group(1) + '-' + m.group(2) + '-' + m.group(3)
    else:
        stnd = phone_mapping[number]
    return stnd

# %%
standardize_phone('0 (44) 52026 08', phone_mapping)
# Out:
# '+38-044-520-2608'

# %%
# Count phones number entries in 'node' and 'way' 'tags'# Count  
t0 = time()
counter = 0 
for event, elem in ET.iterparse(sample_file):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib['k'] == "phone":
                counter += 1
print(time() - t0)
print(counter)
# Out:
# 0.006216526031494141
# 0

# %%
sqlite> SELECT value, COUNT(*) as num
FROM nodes_tags
WHERE key='amenity'
GROUP BY value
ORDER BY num DESC
LIMIT 10;
# Out:
#   File "<ipython-input-97-c09f27433d22>", line 1
#     sqlite> SELECT value, COUNT(*) as num
#                        ^
# SyntaxError: invalid syntax

# %%
sample_file = open("OSM Madrid - XML/sample.osm","rb")
k_values = defaultdict(int)
for event, elem in ET.iterparse(sample_file):
    if elem.tag == 'node':
        pprint(elem.tag.tag)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-5747f090f6fe> in <module>()
#       3 for event, elem in ET.iterparse(sample_file):
#       4     if elem.tag == 'node':
# ----> 5         pprint(elem.tag.tag)
#
# AttributeError: 'str' object has no attribute 'tag'

# %%
#importing cleaned .csv files to SQL schema
CREATE TABLE nodes (
    id INTEGER PRIMARY KEY NOT NULL,
    lat REAL,
    lon REAL,
    user TEXT,
    uid INTEGER,
    version INTEGER,
    changeset INTEGER,
    timestamp TEXT
);

CREATE TABLE nodes_tags (
    id INTEGER,
    key TEXT,
    value TEXT,
    type TEXT,
    FOREIGN KEY (id) REFERENCES nodes(id)
);

CREATE TABLE ways (
    id INTEGER PRIMARY KEY NOT NULL,
    user TEXT,
    uid INTEGER,
    version TEXT,
    changeset INTEGER,
    timestamp TEXT
);

CREATE TABLE ways_tags (
    id INTEGER NOT NULL,
    key TEXT NOT NULL,
    value TEXT NOT NULL,
    type TEXT,
    FOREIGN KEY (id) REFERENCES ways(id)
);

CREATE TABLE ways_nodes (
    id INTEGER NOT NULL,
    node_id INTEGER NOT NULL,
    position INTEGER NOT NULL,
    FOREIGN KEY (id) REFERENCES ways(id),
    FOREIGN KEY (node_id) REFERENCES nodes(id)
);
# Out:
#   File "<ipython-input-95-f628155ad85e>", line 2
#     CREATE TABLE nodes (
#                ^
# SyntaxError: invalid syntax
