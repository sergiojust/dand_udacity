# %%
import sqlite3 as sqlite
import xml.etree.cElementTree as ET
from pprint import pprint
import re
from collections import defaultdict
from time import time
import mapparser
import tags
import users
import audit as adt
import schema
import data
import cerberus
import csv
import codecs
import pprint
import re
import xml.etree.cElementTree as ET

import cerberus

import schema

# %%
osm_file = open("OSM Madrid - XML/madrid_spain.osm","rb")

# %%
sample_file = "OSM Madrid - XML/sample.osm"
t0=time()
k = 10000 # Parameter: take every k-th top level element

def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag

    Reference:
    http://stackoverflow.com/questions/3095434/inserting-newlines-in-xml-file-generated-via-xml-etree-elementtree-in-python
    """
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


with open(sample_file, 'w') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n')
    output.write('<osm>\n  ')

    # Write every kth top level element
    for i, element in enumerate(get_element(osm_file)):
        if i % k == 0:
            output.write(ET.tostring(element).decode('UTF-8'))

    output.write('</osm>')
print(time()-t0)
# Out:
# 43.553579330444336

# %%
def count_tags(filename):
    dict_tags = {}
    for event, elem in ET.iterparse(filename):
        if elem.tag not in dict_tags:
            dict_tags[elem.tag] = 0
        
        dict_tags[elem.tag] += 1
    return dict_tags

# %%
tags = count_tags(sample_file)
pprint(tags)

# %%
osm_file.close()

# %%
def audit():
    for event, elem in ET.iterparse(sample_file, events =("start",)):
        if elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
    pprint(dict(street_types))

# %% [markdown]
# # Lección (Case Study)

# %% [markdown]
# ## Mapparser.py

# %%
s = mapparser.count_tags(sample_file)
pprint(s)
# Out:
# {'member': 3,
#  'nd': 716,
#  'node': 474,
#  'osm': 1,
#  'relation': 1,
#  'tag': 289,
#  'way': 62}

# %% [markdown]
# ## tags.py

# %%
tags.process_map(sample_file)
# Out:
# {'lower': 183, 'lower_colon': 101, 'other': 5, 'problemchars': 0}

# %% [markdown]
# ## users.py

# %%
users.process_map(osm_file)
# Out:
# {'101150',
#  '1068293',
#  '107257',
#  '117664',
#  '123364',
#  '1280319',
#  '13135',
#  '1334676',
#  '1461937',
#  '1504312',
#  '15188',
#  '1580969',
#  '1635134',
#  '165869',
#  '170106',
#  '1722789',
#  '1725553',
#  '1773299',
#  '1803492',
#  '1815833',
#  '18675',
#  '1868925',
#  '1877329',
#  '193123',
#  '1947048',
#  '2019603',
#  '2024941',
#  '2049744',
#  '20587',
#  '2107780',
#  '21080',
#  '2132426',
#  '2153421',
#  '2163609',
#  '219376',
#  '2201799',
#  '2203560',
#  '220932',
#  '223893',
#  '2245342',
#  '2258869',
#  '2267575',
#  '2268702',
#  '2277975',
#  '2295186',
#  '2318',
#  '2481418',
#  '2500',
#  '2587110',
#  '2598444',
#  '267081',
#  '28201',
#  '2909390',
#  '293845',
#  '294608',
#  '3103168',
#  '316694',
#  '3188422',
#  '3196761',
#  '3206597',
#  '3213096',
#  '3225472',
#  '322785',
#  '3251493',
#  '33103',
#  '333621',
#  '344561',
#  '3561701',
#  '3584',
#  '3649461',
#  '366900',
#  '3676505',
#  '370728',
#  '381188',
#  '3829760',
#  '3830020',
#  '40397',
#  '42055',
#  '42123',
#  '427753',
#  '436572',
#  '4369761',
#  '438250',
#  '445671',
#  '45453',
#  '461005',
#  '468314',
#  '472193',
#  '4866290',
#  '491515',
#  '4918711',
#  '4997431',
#  '5032262',
#  '5202428',
#  '526776',
#  '532668',
#  '535609',
#  '5379200',
#  '5530',
#  '568647',
#  '587703',
#  '622785',
#  '6389',
#  '648006',
#  '651622',
#  '690682',
#  '6959806',
#  '699830',
#  '708476',
#  '7142889',
#  '7164379',
#  '718437',
#  '7215820',
#  '7328364',
#  '73791',
#  '777223',
#  '8076',
#  '860575',
#  '86401',
#  '86541',
#  '87939',
#  '915419',
#  '971'}

# %% [markdown]
# ## audit.py

# %%
adt.audit(osm_file)
# Out:
# Glorieta de Bilbao
# Fuencarral
# Calle de la Luna
# Calle de Alfonso XII
# Calle de Ponferrada
# Plaza de la Cebada
# Calle Toledo
# Calle Nuestra Señora de la Luz
# Calle del Ave María
# Calle de San Mateo
# Plaza de Cristino Martos
# Plaza del Conde de Toreno
# Calle del Duque de Osuna
# Calle del Conde Duque
# Calle de Campomanes
# Calle de Fernando VI
# Calle de Donoso Cortés
# Plaza del Comandante Las Morenas
# Calle de la Unión
# Calle de Melchor Fernández Almagro
# Avenida de Betanzos
# Calle Melchor Fernández Almagro
# Calle de Ribadavia
# Plaza Redondela
# Plaza de la Cebada
# Calle de la Cava Baja
# Plaza del Humilladero
# Costanilla de San Andrés
# Calle de Ginzo de Limia
# Calle de La Bañeza
# Avenida de Brasil
# Calle de Bravo Murillo
# Calle de Matilde Landa
# Calle de las Magnolias
# Calle de los Mártires de la Ventilla
# Calle Isidro Fernández
# Calle Virgen de Aránzazu
# Calle de San Modesto
# Calle de Virgen de Aránzazu
# Calle del Conde de la Cimera
# Calle Beatriz de Bobadilla
# Calle de Juan Montalvo
# Calle Melchor Fernández Almagro
# Calle de Villa de Marín
# Calle del Doctor Esquerdo
# Plaza Padron
# Calle de Atocha
# Paseo del Prado
# Calle Fúcar
# Calle de Moratín
# Calle de la Alameda
# Paseo del Prado
# Calle de Moratín
# Calle Huertas
# Calle de las Huertas
# Calle de Jesús
# Calle de Lope de Vega
# Plaza de Jesús
# Plaza de Jesús
# Paseo del Prado
# Paseo de Recoletos
# Calle de los Embajadores
# Calle de Sebastián Herrera
# Calle de Sebastián Elcano
# Calle Mayor
# Calle Mayor
# Calle Mayor
# Plaza de San Miguel
# Plaza San Miguel
# Calle de Santiago
# Calle de Santiago
# Calle de Santiago
# Costanilla de Santiago
# Calle Mayor
# Pasadizo de San Ginés
# Calle de Coloreros
# Calle Mayor
# Calle Arenal
# Calle Caños del Peral
# Calle Caños del Peral
# Calle de las Veneras
# Calle Costanilla de los Ángeles
# Calle Preciados
# Calle Preciados
# Calle de las Veneras
# Plaza de San Martín
# Calle del Postigo de San Martín
# Calle del Carmen
# Calle Preciados
# Calle de Galdo
# Calle del Carmen
# Calle de Tetuán
# Calle de la Salud
# Plaza del Carmen
# Calle de Francia
# Calle de Clara Schumann
# Calle de Lituania
# Calle de los Berrocales
# José Hierro
# Calle de Paz Camacho
# Calle de las Panaderas
# Calle de Federica Montseny
# Calle Arturo Soria
# Calle de los Montes de Barbanza
# Calle Rosalía de Castro
# Avenida de Mataespesa
# Calle de los Montes de Barbanza
# Calle de las Sicélidas
# Calle Capitán Salazar Martínez
# Calle de José Ortega y Gasset
# Calle de Santiago Ramón y Cajal
# Calle de los Molinos
# Calle Paulonia
# Calle de Benjamín Palencia
# Calle de Ligonde
# Calle de Culla
# Avenida del Somorrostro
# Calle de Melilla
# Calle del Poeta Joan Maragall
# Avenida de Bruselas
# Calle de Pío Baroja
# Avenida del Doctor García Tapia
# Calle de la Sierra de Filabres
# Calle El Bosco
# Calle de Antonio López
# Calle Magallanes
# Calle Jaime Vera
# Calle de Gonzalo de Córdoba
# Calle de Anabel Segura
# Calle de los Montes de Barbanza
# Calle de Zurich
# Calle Nueva York
# Calle de José del Prado y Palacio
# Calle del Pico de los Artilleros
# Avenida de Canillejas a Vicálvaro
# Avenida de Castilla
# Calle Camino de la Esgaravita
# Avenida del Alcalde José Aranda
# Calle del Limonero
# Calle de la Iglesia
# Avenida de Alfonso XIII
# Avenida del Doctor García Tapia
# Calle Santa Emilia
# Calle de Manuel Azaña
# Calle San Pedro
# Calle Estrella Polar
# Calle Valle del Sella
# Calle de Gravina
# Calle de Santa Engracia
# Calle Caroli
# Campezo
# Calle del Príncipe Carlos
# Calle del Principe Carlos
# Calle del Príncipe Carlos
# Calle de Madrid
# Avenida Puerta de Madrid
# CR CM-1002 P.K. 26,70 D
# CR N-400, 56,8
# CARRETERA CTRA.N-301 KM. 67
# CR M-300, 30.3
# CARRETERA M-300 KM. 13
# CTRA: M-218 ESQ. C/ DUERO - POLÍGONO INDUSTRIAL
# Avenida de Madrid
# CL CARRETERA ARANJUEZ ,56 (CR M-305 (M-305 KM 19.8)
# AVDA DE MADRID
# Calle de Noblejas
# Avenida de Madrid
# AVDA. SAN PABLO
# Calle de la Presa
# Avenida Martin Luther King
# Autovía del Este
# AVENIDA RIO DUERO
# CR M-103, 23,5
# CR ALGETE KM 5.80
# Calle Torrelaguna
# AV. CASTILLA
# CARRETERA COMARCAL M236 KM 51.600
# AUTOVIA A-3 KM 62.5
# NACIONAL 320 km 276
# Autovía A2 KM 49.68
# CAMINO SAN MARTIN CTRA. FONTANAR
# Autovía A-2, km.45,6
# Avenida de la Industria. Vial UP10 (C.C. Eroski)
# Avenida de Castilla La Mancha
# N-400 KM 82.4
# CL FRANCISCO ARITIO  97
# AVDA. DEL ANTIGÜO FERROCARRIL, Nº 1
# CRTA. N-III PK. 41,00
# Carretera N-320 Km. 289,7 D
# CL AVENIDA ALCALA
# CR GU-102, Km. 2.350
# Calle de López de Hoyos
# Calle del Arroyo de las Pilillas
# CR M-603, 14,1
# Calle del Doctor Esquerdo
# Avenida del Monte Igueldo
# Paseo del Marqués de Zafra
# Avenida de Concha Espina
# A-4 KM 23.3
# Calle de María de Molina
# Calle de Nuestra Señora de Valverde
# Paseo de La Habana
# Calle de Goya
# Avenida de Monforte de Lemos
# Calle Aníbal
# CL AV DE LA INDUSTRIA
# Calle de Antonio López
# CL.AGUILAS (P. IND. PINTO ESTACIÓN)
# Avenida Real de Pinto
# Calle de Alberto Aguilera
# Calle de Sangenjo
# CTRA. MADRID TOLEDO km 10
# Paseo de Santa María de la Cabeza
# Calle del Aguacate
# CR M-506
# Autovía de Toledo
# CALLE FELIPE CALLEJA, S/N
# Autovía de Colmenar
# Paseo de la Ermita del Santo
# M-203 (MADRID-VICALVARO) km 3600
# M-203 (MADRID-VICALVARO) km 3600
# Avenida de la Constitución
# C/ CAMPEZO, 7 km CENTRO COMERCIAL M
# Avenida General
# CTRA. BURGOS
# Avenida de Logroño
# CR M-214, 4,6
# CR A-3 MG IZDO, KM 11.2 KM 11.200
# C/ CTRA. ANDALUCÍA
# CTRA. N-I KM 64.650
# Avda. Vicálvaro esq. Pobladura del Valle
# M-40, PK 7.4 - ACCESO AL CAMPO DE LAS NACIONES
# AVDA. GENERALISIMO,12
# CR C-9, 31 (C-9 KM 31.4)
# Calle Pobladura del Valle
# Avenida de Arcentales
# AUTOP. VALENCIA KM 7.1
# CL ALAMO, PL INDS LOS HUERTECILLO 49 (AV DE LA CONSTITUCION 167)
# Avenida de Machupicchu
# CL BOULEVARD SALVADOR ALLENDE, 12-1
# Calle de Silvano
# CTRA. N-IV km 32
# CARRETERA COMARCAL 400 KM 2.810
# CARRETERA TOLEDO-MOCEJON KM 4.300
# CARRETERA M-509 KM 4.4
# CTRA. 607 (DE COLMENAR A NAVACERRADA) KM 48.2
# CR A-5, 23.5
# Vía de servicio A-6
# CTRA. M-505 KM 5.5
# CARRETERA M-505 km 5.5
# CR A-42, 47,3
# Calle Fresadores
# CR.VILLALUENGA-COBEJA (TO-4512-V km P.K.2,0)
# Vía de servicio A-6
# CR A-5
# CR M-856 (ENLACE N-V Y N-501) km 1
# CALLE COPENHAGUES/N, S/N
# CTRA. NACIONAL V, (el soto) KM 19.0
# CR A-42, 42,8
# CL DR.MARAÑON C/V PL ESCORIAL, S.N.
# AVDA DEL VALLE 36 (CRTA M 604 KM 24.100)
# PASEO DE LA ERMITA, S/N.
# CARRETERA N-VI KM 43.2
# CTRA. TOLEDO-BARGAS, KM 1.700
# Calle Escofina
# Carretera de Navacerrada
# Carretera de Navacerrada
# CR A-42, 63,30 I
# CR A-42 P.K. 63,30 D
# POLIGONO ALPARACHE, S/N
# M-608 km 38
# CALLE DOCTOR CABAÑAS
# CL JARAMA (POLG. INDUST.PAR,22), S.
# CM-4001 km 23
# Avenida de los Castillos
# CALLE EBANISTAS,
# CTRA. BOADILLA KM 1.0
# SAN BERNARDO, S/N - Bº DE LA FORTUNA
# CL BARLOVENTO
# CL PASEO GALATEA, 35 (TO-423 KM 10.9)
# CR PARLA-PINTO, KM. 0.15
# CR M-406 , P.K. 7,3
# Calle del Real
# AVDA ARCAS DE AGUA SN
# CERRO DE LA VEGA, S/N.
# Avenida de Europa
# POL. IND. VALDELASILLA - C.C. CAPRABO
# GLORIETA LOS JAZMINES, S/N
# Calle Carlos I
# CARRETERA M-515 KM. 2
# L-14 OCAÑA-PTE. PEDRERA KM 39.5
# CR M-506 MOSTOLES-FUENLABRADA KM. 4
# CR MOSTOLES-FUENLABRADA, KM.4
# CALLE CAMINO LEGANES
# AVENIDA FUENLABRADA
# CARRETERA CM-4010 KM. 2
# CL AVDA. S. MARTIN DE VALDEIGLE, S. (M-501 KM 0.3)
# CC. LORANCA ALCAMPO FUENLABRADA (AV. PABLO IGLESIAS, S/N, CIUDAD LORANCA)
# AV DE MOSTOLES, Nº 6
# AVENIDA LA INDUSTRIA, S/N
# CTRA. N-V KM 12.5
# CR A-42, 32,8
# CL-601 (VALLADOLID-SEGOVIA) km 105
# CM-4003 km P.K.32,4
# C. C. LUZ DE CASTILLA - CTRA. DE SAN RAFAEL, N- 603
# C.N.-603-MARGEN DERECHO km 93.60000
# C.N.-603-MARGEN IZQUIERDO km 93.60000
# CARRETERA M-600 KM. 14
# C/Las Pozas, s/n - P.I. Matacuervos
# CL PASEO EZEQUIEL GONZALEZ
# CALLE CAMINO DE LA FABRICA, S/N
# Avenida de Felipe II
# CR CM-401, 9,2 M.D.
# CARRETERA L 54 KM. 7
# CTRA, N-V km 37550
# CARRETERA N-V KM. 40
# CARRETERA M-501 KM. 27
# CARRETERA N-110 A SORIA KM 189 PARKING SUPERMERCADO KM. 110
# AVENIDA TOLEDO
# AVENIDA TOLEDO
# AVENIDA TOLEDO
# CM-4009 km P.K.14,4
# CL-605 km 1
# AVDA. ALTO DEL LEÓN, Nº 3
# TO-4421-V km P.K.10,2
# Avenida de Santiago
# CTRA MADRID-BADAJOZ N-5 KM 57.6
# Calle del Prado
# Calle Cañada Nueva
# Calle de José Abascal
# Calle de María Tubau
# Calle de Burguete
# Calle de Mateo Inurria
# Avenida de Alfonso XIII
# Plaza Sagrados Corazones
# Calle del Príncipe de Vergara
# Calle del Cañaveral
# Paseo de la Castellana
# Calle de los Mártires de la Ventilla
# Calle Santa Hortensia
# Calle Ramón Rubial
# Calle de Montalbán
# Calle de Montalbán
# Paseo de la Castellana
# Paseo de la Castellana
# Paseo de la Castellana
# Ronda Ingenioso Hidalgo
# Calle Ocaña
# Avenida de Nuestra Señora de Fátima
# Calle de la Sierra Toledana
# Calle de Santa Engracia
# Calle de Bravo Murillo
# Calle de Bravo Murillo
# Calle de Bravo Murillo
# Calle de Bravo Murillo
# Calle de Bravo Murillo
# Calle de Bravo Murillo
# Calle de Pinos Alta
# Calle Pinos Alta
# Avenida de Asturias
# Plaza de Castilla
# Calle Sabadell
# Calle Molins de Rey
# Calle de las Islas Palaos
# Calle de Nuestra Señora de Valverde
# Calle de Nuestra Señora de Valverde
# Calle de Arturo Soria
# Calle de Arturo Soria
# Avenida de Manoteras
# Avenida de Manoteras
# Calle de Bahía de Málaga
# Calle Río Guadiana
# Calle Ramón y Cajal
# Calle General Ricardos
# Calle Pinto
# Calle Cuba
# Calle Pio XII
# Calle Pinto
# Avenida de las Estrellas
# Calle Estrella Polar
# Calle Estrella Polar
# Calle Jaime I El Conquistador
# Calle Isabel II
# Calle La Sal
# Calle Cuenca
# Calle Libreros
# Calle de la Bahía de Gando
# Calle de Querol
# Calle de Arturo Soria
# Calle de Federico García Lorca
# Calle de Federico García Lorca
# Avenida de Concha Espina
# Calle del Corazón de María
# Calle San Cipriano
# Calle de Manuel Fernández y González
# Calle de Ventura de la Vega
# Calle Parroquia
# Plaza Mayor
# Calle del General Lacy
# Calle de las Delicias
# Calle del General Lacy
# Calle del General Lacy
# Calle del General Lacy
# Calle del Ferrocarril
# Calle del Ferrocarril
# Calle del Ferrocarril
# Calle Alba
# Calle de Sinesio Delgado
# Calle de Edgar Neville
# ZONA AEROPUERTO DE BARAJAS, T4, S/N
# Calle Cirilo Cantero
# AVENIDA AURELIO ALVAREZ, S/N
# M-603 (FUENCARRAL - ALCOBENDAS) KM 14.9
# CALLE CARRETERA SAN RAFAEL
# DIAZ CORDOBES, S/N.
# CALLE ARTURO DUPERIER, S/N
# AVENIDA AVDA. DE LA CABRERA S/N JUNTO AL HOSTAL EL CANCHO DEL AGUILA (A-1 KM 60), S/N
# AUTOVIA NACIONAL I KM 26.200
# Calle Villamalea
# CALLE INMACULADA
# CARRETERA M-501 KM 40.500
# Camino del Cuartel
# CARRETERA M-311 KM 19.4
# AVENIDA DE LA TECNICA, S/N
# CALLE CARDENAL GONZÁLEZ DE MENDOZA, S/N
# CARRETERA M-233 KM 6.800
# CARRETERA ANTIGUA NACIONAL I KM 15.5
# Calle de Francos Rodríguez
# Calle Rioja
# Avda de la Hispanidad 20
# Avenida de Fuenlabrada
# Carretera CR GU-221 KM 20.6
# AVENIDA RIO GUADALQUIVIR
# Calle Arroyo de la Hiruela
# CARRETERA FONTANAR KM. 1
# CARRETERA C-302 KM 38.40
# CARRETERA FUENCEMILLAN-ESPINOSA S/N (CARRETERA km 38)
# Avenida de las Flores
# CALLE REAL, S/N
# CARRETERA N-403 KM 17.300
# AVENIDA SAN PABLO
# CARRETERA N-110 KM 182.650
# AVENIDA CONSTITUCION
# Plaza de Setúbal
# CALLE FRANCISCO ARITIO, S/N
# CARRERA VALENCIA, KM 14.800
# Calle Miguel de Cervantes
# CARRETERA CM-4000 KM 2.650
# Calle de Doradores
# Calle Alameda del Fresno
# Calle de Antonio Machado
# POLIGONO LA CARBONERA, S/N
# Calle del General Yagüe
# Calle de Colombia
# Calle de Toledo
# Carretera M-9100 Km. 4
# Ctra. N-IV KM 55.200
# Avenida del Mayorazgo
# CALLE CAMINO PORTASAGO, S/N
# CALLE SANTA MISION
# Calle Camino de Valladolid
# CARRETERA M-405 KM 5.6
# Carretera Nacional II Km. 47,50
# Calle del Doctor Gómez Ulla
# ZONA PLATAFORMA AEROPUERTO BARAJAS T123, S/N
# Calle de Villalonso
# AVENIDA PORTUGAL (IZDO)
# Calle del Príncipe de Vergara
# CARRETERA N-400 KM 24.6
# CALLE SESEÑA
# AVENIDA VALDELAPARRA (DE)
# CALLE ARAGON
# CARRETERA CL-601 KM 100.800
# Carretera GU-102 Km. 3.2
# Avenida Juan Carlos I
# CARRETERA CM-101 KM. 0
# CARRETERA M-507 KM 6.700
# CALLE GENERALISIMO
# Avenida de Guadalajara
# CARRETERA VALDEMAQUEDA KM. 0
# CALLE GENERALISIMO
# Avenida de Francia
# AUTOVIA E-901/A-3 KM 35.2
# CARRETERA M-623 KM 1.5
# Calle Rioja
# AVENIDA AVDA DEL SOL ESQ.AVDA DE FRANCIA, SN
# CARRETERA CARRETERA TOLEDO KM 80.250
# CARRETERA M506 PK 26 KM. 26
# Vía Complutense
# CL FRAY JOSE DE SAN JACINTO 10
# CALLE LUIS SAUQUILLO
# Calle Malacuera
# Plaza de la República Argentina
# Ctra. N-IV KM 55.200
# CL AVENIDA CASTILLA LA MANCHA, 79 (N-401 KM 35.5)
# CAMINO DEL VENTORRILLO, S/N
# CARRETERA M-305 KM. 5
# AVENIDA HISPANIDAD
# Calle Real de Arganda
# PASEO DE LA HERMITA DE STA. ANA
# CALLE NARCISO MONTURIOL
# CARRETERA M-405 KM. 6
# CARRETERA N-320 KM 314.500
# CARRETERA M-300 KM 8.1
# POLIGONO INDUSTRIAL BOADILLA PARCELAS 2-3-4, S/N
# CARRETERA C L 605 DE SEGOVIA A ZAMORA KM. 14
# CALLE ALCALA
# AUTOVIA A-1 KM 29.1
# POLIGONO INDUSRIAL PINARES LLANOS, C/CARPINTEROS, S/N
# POLIGONO CENTRO LOGISTICO DE ABASTECIMIENTO-PARCELA
# CL CALVARIO 10
# CARRETERA M208 KM 9.600
# AVENIDA PORTUGAL (DE)
# Avenida de España
# Carretera Alcalá-Pastrana Km 4,400
# Calle Guadalajara
# Avenida de Santiago
# Avenida de los Poblados
# CARRETERA M-404 KM 39.8
# Avenida de Pío XII
# TR DEL DESVIO 19
# AUTOPISTA AUTOPISTA AP41 KM 31.760
# CALLE CERRO SAN PEDRO
# CR CM-219, 4,9
# CARRERA CARRETERA DE CRIÑON, S/N
# AVENIDA QUITAPESARES
# AUTOVIA A-3 KM 71.9
# Carretera M-300 Km 26.4
# AVENIDA CASTILLA LA MANCHA
# Avenida del Atance
# AUTOPISTA AUTOPISTA AP-41 KM 31.780
# PLAZA HUERTA DE LAS FLORES
# Calle de la Inmaculada
# AVENIDA MADRID
# POLIGONO FRANCISCO MEDINA Y MENDOZA PARCELA 10, S/N
# Calle Primavera
# CR M-406 KM 10
# C/. SAN PEDRO
# Calle de Cavanilles
# CARRETERA M-404 KM. 31
# M-103 km 6.207
# Avenida Boladiez (C.C. Eroski - Luz del Tajo), SN
# Calle Madrid
# AVENIDA DE CASTILLA LA MANCHA 54 (TO-413 km 33)
# CALLE JULIAN BESTEIRO, S/N
# CARRETERA ARANJUEZ- ONTIGOLA KM 2.700
# Avenida de Valdelaparra
# CARRETERA M-501 KM 17.2
# AUTOVIA A-42 KM 57.700
# M-103 km 6.210
# CALLE PEDRO GARRIDO, S/N
# Calle Arroyo del Soto
# CALLE NUEVA, S/N
# Avenida de las Trece Rosas
# Calle Puerto de Navacerrada - POLIGONO INDUSTRIAL PRADOVERA
# CARRETERA N-II KM. 38
# AVENIDA PESETA
# Calle de los Embajadores
# CARRETERA M-506 KM. 4
# Paseo de la Castellana
# Avenida de Castilla
# PLAZA MORALEJA S/N, S/N
# CARRETERA TOLEDO -CUESTA LA REINA KM 10.200
# CALLE NAVALPINO
# CL MADRID
# CALLE SEGOVIA C/V A PASEO VIRGEN DEL PUERTO, S/N
# PASEO ESTACION, S/N
# AVENIDA EUROPA (C.C. LA MORALEJA), 13/15
# CALLE CTRA. OCAÑA
# Carretera de Andalucía
# CARRETERA M 506 KM 4.900
# CARRETERA M-610 KM 19.8
# CARRETERA CABANILLAS A BUSTARVIEJO KM 5.320
# CALLE HERNANDEZ TEJADA, S/N ESQ. AGASTIA, S/N (A-2 KM 5.1), S,N
# CARRETERA C-404 KM. 28
# CARRETERA MADRID-TOLEDO KM 57.700
# Calle Ramón y Cajal
# AVENIDA FUENTENUEVA
# Avenida Ensanche de Vallecas
# Calle Londres
# CARRETERA M222 KM. 19
# Paseo de San Francisco de Sales
# Calle de Nuestra Señora del Carmen
# Calle de Jorge Juan
# Calle de Suiza
# Calle de Alcalá
# Castilla
# Calle Botoneras
# Calle de Valdeláguila
# CARRETERA M-501 KM. 27
# CALLE EXTRAMUROS, S/N
# CALLE FRANCISCO MEDINA Y MENDOZA, P.4-18
# CARRETERA CM-4004 KM 17.50
# CALLE PUENTE SAN ROQUE
# Calle Ansar
# Calle Viñegra
# Calle Viñegra
# Calle Viñegra
# Calle Viñegra
# Calle Viñegra
# Calle Viñegra
# Calle Viñegra
# Calle Viñegra
# Calle del Concejal Francisco José Jiménez Martín
# Calle del Concejal Francisco José Jiménez Martín
# Calle del Concejal Francisco José Jiménez Martín
# Ciudad Jardín del Rosario
# Calle de Grecia
# Calle de Grecia
# Avenida de las Provincias
# Calle de Orense
# Calle del Río
# Ctra. Villalba a Moralzarzal
# Calle del Azufre
# Calle del Azufre
# Paseo de la Chopera
# Calle de las Conchas
# Calle de los Trujillos
# Cuesta de Santo Domingo
# Plaza de Santo Domingo
# Calle de la Flor Baja
# Gran Vía
# Plaza de los Mostenses
# Calle de la Cañada
# Calle Amoniaco
# Calle de la Solana
# Calle del Grafito
# Calle del Grafito
# Calle del Grafito
# Calle del Grafito
# Calle del Grafito
# Calle del Grafito
# Calle de Quintana
# Calle de Guzmán el Bueno
# Hermandad Donantes Sangre
# Calle Real
# Calle Real
# Calle de Valdelamasa
# Calle de Valdelamasa
# Calle de Valdelamasa
# Calle de Valdelamasa
# Calle de Valdelamasa
# Calle de Valdelamasa
# Calle de Cabeza Grande
# Calle de Cabeza Grande
# Calle de Cabeza Grande
# Calle Atalaya
# Calle Atalaya
# Calle de la Fuente
# Calle de las Covachuelas
# Calle de las Covachuelas
# Calle de la Fuente
# Calle de las Procesiones
# Calle de las Procesiones
# Calle de Arlabán
# Calle de Cebreros
# Calle de Echegaray
# Calle de Echegaray
# Calle de Echegaray
# Calle de Bailén
# Avenida del Ventisquero de la Condesa
# Calle de los Riscos de Polanco
# Avenida del Marqués de Corbera
# Calle de San Bernardo
# Calle de Alonso Cano
# Calle de Serrano
# Calle de Manuel Pombo Angulo
# Calle de Rodríguez San Pedro
# Calle de Galileo
# Calle de Santa Cruz de Marcenado
# Calle de Galileo
# Glorieta de Ruiz Jiménez
# Calle de Alberto Aguilera
# Calle de Carranza
# Calle de Magallanes
# Calle de Alberto Aguilera
# Calle de Alberto Aguilera
# Calle de los Albatros
# Calle de los Albatros
# Avenida de la Reina Victoria
# Avenida de la Reina Victoria
# Calle de Bravo Murillo
# Calle de Bravo Murillo
# Calle de Alberto Aguilera
# Calle de Alberto Aguilera
# Calle del Acuerdo
# Calle del Acuerdo
# Calle del Acuerdo
# Calle del Acuerdo
# Calle del Conde Duque
# Calle del Conde Duque
# Glorieta Ruiz Jimenez
# Calle de Alberto Aguilera
# Glorieta de Ruiz Jiménez
# Glorieta de Ruiz Jiménez
# Calle de Magallanes
# Calle de Magallanes
# Calle de Fernández de los Ríos
# Calle de Vallehermoso
# Calle de Bolivia
# Calle de Argensola
# Calle de Serrano
# Calle de Melilla
# Calle de Barceló
# Calle de Manuela Malasaña
# Calle de la Infanta Mercedes
# Calle Real
# Paseo del Pintor Rosales
# Calle del Doctor Urquiola
# Calle de las Tintas
# Calle del Espinar
# Calle de la Oca
# Calle de Móstoles
# Calle de los Andes
# Calle de Andrés Mellado
# Plaza del Mercado
# Calle Arcipreste de Hita
# Plaza del Mercado
# Avenida Castilla La Mancha
# Avenida Castilla La Mancha
# Avenida Castilla La Mancha
# Plaza del Mercado
# Calle Arcipreste de Hita
# Plaza del Mercado
# Calle Arcipreste de Hita
# Plaza del Mercado
# Calle Arcipreste de Hita
# Plaza del Mercado
# Plaza del Mercado
# Plaza del Mercado
# Plaza del Mercado
# Avenida Castilla La Mancha
# Calle de Diego de León
# Calle de Bretón de los Herreros
# Avenida de Felipe II
# Calle de Argumosa
# Calle de Narváez
# Calle Buenos Aires
# Calle Cuba
# Calle Cuba
# Calle de Luis I
# Calle Uruguay
# Calle del Grafito
# Calle de la Forja
# Calle del Grafito
# Calle del Grafito
# Calle del Grafito
# Calle del Grafito
# Calle del Grafito
# Calle de la Forja
# Calle del Grafito
# Calle del Grafito
# Calle de la Huerta
# Paseo de El Pardo
# Paseo de El Pardo
# Paseo de El Pardo
# Paseo de El Pardo
# Paseo del Prado
# Paseo del Prado
# Calle de Alcalá
# Calle de Zorrilla
# Calle de Burgos
# Calle de Burgos
# Calle de Juan del Risco
# Calle de Burgos
# Calle del Marqués de Casa Riera
# Calle Petra Sánchez
# Paseo de Extremadura
# Calle de la Rosa
# Calle de la Era Honda
# Calle Albatros
# Calle Albatros
# Calle Nuestra Señora del Valle
# Calle de Numancia
# Calle Ramón y Cajal
# Calle Ramón y Cajal
# Calle Ramón y Cajal
# Calle Nuestra Señora del Valle
# Calle Ramón y Cajal
# Calle Ramón y Cajal
# Calle Ramón y Cajal
# Calle Ramón y Cajal
# Calle Ramón y Cajal
# Calle Nuestra Señora del Valle
# Calle Nuestra Señora del Valle
# Calle Nuestra Señora del Valle
# Calle Ramón y Cajal
# Calle Nuestra Señora del Valle
# Calle Nuestra Señora del Valle
# Calle Ramón y Cajal
# Calle Nuestra Señora del Valle
# Calle Ramón y Cajal
# Calle Murillo
# Calle Murillo
# Calle Romeral
# Calle de Miguel Ángel
# Calle Romeral
# Calle de Miguel Ángel
# Calle de Miguel Ángel
# Calle de Miguel Ángel
# Calle de Miguel Ángel
# Calle de Miguel Ángel
# Calle Romeral
# Calle de Miguel Ángel
# Calle de Miguel Ángel
# Calle Yuncos
# Calle de Numancia
# Calle de Miguel Ángel
# Calle Yuncos
# Calle de Numancia
# Calle de Miguel Ángel
# Calle de Numancia
# Calle de Numancia
# Calle Murillo
# Calle Romeral
# Calle El Carpio del Tajo
# Calle de Numancia
# Calle El Carpio del Tajo
# Calle de Numancia
# Calle de Miguel Ángel
# Calle de Numancia
# Calle Murillo
# Calle Romeral
# Calle de Miguel Ángel
# Calle Romeral
# Calle Murillo
# Calle Romeral
# Calle de Miguel Ángel
# Calle Murillo
# Calle Romeral
# Calle Romeral
# Calle Reina Victoria
# Pintor Rivera, 1 posterior
# Calle de Serrano
# Carretera Soria-Plasencia Km 182
# Calle Real
# Calle Real
# Sor Livia Alcorta
# Calle Estafeta Vieja
# Calle Estafeta Vieja
# Calle Estafeta Vieja
# Calle Real
# Calle Real
# Calle Real
# Calle Puerta del Sol
# Calle Real
# Calle Real
# Calle de los Mártires
# Calle de los Mártires
# Calle de los Mártires
# Calle de los Mártires
# Calle Calesas
# Calle Hermenegildo Bielsa
# Calle Juan de Vera
# Calle de Isaac Peral
# Paseo de Santa María de la Cabeza
# Calle de San Magín
# Calle General Margallo
# Calle del Príncipe de Vergara
# Calle de la Estrella Hadar
# Calle de Villagarcía
# Calle de Villagarcía
# Calle de Villagarcía
# Calle de Villagarcía
# Calle de Villagarcía
# Calle de Villamanín
# Calle de Villagarcía
# Calle de Villasandino
# Calle de Villamanín
# Calle de Villamanín
# Calle de Villamanín
# Calle de Villamanín
# Calle de Villagarcía
# Calle de Villagarcía
# Calle de Illescas
# Calle de Villamanín
# Calle de Villamanín
# Calle María Moliner
# Calle de Colón
# Calle del Doctor Piga
# Calle de las Huertas
# Calle de los Reyes
# Plaza del Emperador Carlos V
# Calle de San Vicente Ferrer
# Calle de Sánchez Bustillo
# Calle del Doctor Mata
# Plaza del 2 de Mayo
# Calle del Doctor Piga
# Calle de Fuencarral
# Calle de Fuencarral
# Fuencarral
# Calle Mayor
# Calle Estrella Antares
# Calle Estrella Antares
# Avenida Ensanche de Vallecas
# Paseo de Extremadura
# Calle de San Andrés
# Calle de la Reina
# Calle de la Reina
# Calle de Hortaleza
# Calle del Clavel
# Corredera Baja de San Pablo
# Calle de la Reina
# Calle de la Reina
# Calle de Segovia
# Avenida del Doctor García Tapia
# Avenida del Doctor García Tapia
# Calle de la Hermandad Donantes Sangre
# Hermandad Donantes Sangre
# Calle de la Hermandad Donantes Sangre
# Call de la Hermandad de Donantes Sangre
# Calle de Anoeta
# Avenida del Padre Piquer
# Calle de Argumosa
# Calle de Covarrubias
# Calle de Isaac Peral
# Hermandad de Donantes de Sangre
# Calle del Salado
# Calle de Santa María Reina
# Calle de Santa María Reina
# Calle de Santa María Reina
# Gran Vía
# Calle de Jesusa Lara
# Plaza de Epifanio Velasco
# Calle Camino de Valladolid
# Calle de las Cuatro Matejas
# Avenida de la Comunidad de Madrid
# Paseo de La Habana
# Calle de Potosí
# Avenida de Viñuelas
# Calle de Mira el Sol
# Calle de Federico García Lorca
# Calle de Jesusa Lara
# Calle de Jesusa Lara
# Calle Antonio Muñoz Manzaneque
# Calle de Jesusa Lara
# Calle de la Señora Sergia
# Calle de Roma
# Calle de Roma
# Calle de Roma
# Calle de Roma
# Calle de Roma
# Calle de Roma
# Calle del Real de San Sebastián
# Avenida del Talgo
# Calle de los Cabestreros
# Calle de Lavapiés
# Calle de Argumosa
# Calle de las Amazonas
# Calle Caños del Peral
# Calle del Congosto
# Paseo de Federico García Lorca
# Calle Real de Arganda
# Calle Real de Arganda
# Calle de Albadalejo
# Calle de la Solana
# Calle de la Solana
# Calle del Metano
# Calle Fuentidueña
# Calle Amoniaco
# Calle Amoniaco
# Calle Amoniaco
# Calle Amoniaco
# AVENIDA DE LA CIRCUNVALACION
# Calle del Ferrocarril
# Calle del Ferrocarril
# Calle del Ferrocarril
# Calle del Ferrocarril
# Calle del Ferrocarril
# Calle del Ferrocarril
# Calle del Ferrocarril
# Calle de Lavapiés
# Calle de Lavapiés
# Calle de Atocha
# Calle de Rosario Manzaneque
# Calle de Rosario Manzaneque
# Calle de Antonio Lasso
# Calle de Antonio Lasso
# Calle de Antonio Lasso
# Calle Flor de Lis
# Calle de Los Ángeles
# Calle Flor de Lis
# Calle Flor de Lis
# Plaza Epifanio Velasco
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Flor de Lis
# Plaza de la Iglesia
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Profesor Alonso Parra
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Flor de Lis
# Calle Profesor Alonso Parra
# Calle Flor de Lis
# Calle de Valladolid
# Profesor Waksman, 5
# Profesor Waksman 6
# Calle de Torrelodones
# Calle de Torrelodones
# Calle de Torrelodones
# Calle de Torrelodones
# Calle de Torrelodones
# Calle de Torrelodones
# Carretera de Galapagar a Colmenarejo
# Carretera de Galapagar a Colmenarejo
# Calle de Fuentetodos
# Calle de Fuentevaqueros
# Calle de Santa Ana
# Calle de la Plaza
# Carretera de Mejorada a San fernando de Henares Km 0,100
# Avenida de la Hispanidad
# Calle de Leganés
# Calle de la Paz
# Calle de la Plaza
# Calle del Higueral
# Calle del Higueral
# Avenida de la Cañada
# Avenida de España
# Calle Camarena
# Calle de San Bernardo
# Calle de Extremadura
# Calle de Extremadura
# Calle de Extremadura
# Av. de los Ébanos
# Calle de Blasco de Garay
# Avenida Conde de las Almenas
# Calle de Extremadura
# Calle de Extremadura
# Calle del Higueral
# Calle de Extremadura
# Calle de Extremadura
# Calle Principal
# Calle de Lourdes
# Calle de Pío Baroja
# Calle del Marqués de Santilla
# Calle del Sauce
# Calle Rio Duero, 24
# Calle de Antonio Arias
# Plaza del Doctor Laguna
# Calle de Jerónimo del Moral
# Calle de Latoneros
# Calle Fuente del Berro
# C/ San Joaquín nº5
# Rotonda de Pitágoras
# Calle de Alcalá
# Calle de Atocha
# Calle Aguilón
# Plaza del Doctor Laguna
# Calle del Doce de Octubre
# Calle del Doce de Octubre
# Calle del Doce de Octubre
# Plaza del Doctor Laguna
# Plaza del Doctor Laguna
# Calle del Doce de Octubre
# Calle del Doce de Octubre
# Plaza del Doctor Laguna
# Calle del Doce de Octubre
# Calle del Doce de Octubre
# Calle Doce de Octubre
# Calle de Máiquez
# Calle del Doce de Octubre
# Calle de Pío Baroja
# Calle del Doce de Octubre
# Calle del Doce de Octubre
# Calle del Doce de Octubre
# Calle Alcalde Sáinz de Baranda
# Calle Alcalde Sáinz de Baranda
# Calle del Doce de Octubre
# Calle Libertad
# Calle Doctor José María Poveda
# Calle Doctor José María Poveda
# Calle de Hilarión Eslava
# Calle de Lourdes
# ...
#               'Plaza del Comercio',
#               'Plaza del Conde',
#               'Plaza del Conde de Barajas',
#               'Plaza del Conde de Casal',
#               'Plaza del Conde de Elda',
#               'Plaza del Conde de Miranda',
#               'Plaza del Conde de Toreno',
#               'Plaza del Conde del Valle Suchil',
#               'Plaza del Conde del Valle de Suchil',
#               'Plaza del Consistorio',
#               'Plaza del Corregidor Alonso de Aguilar',
#               'Plaza del Corregidor Sancho de Córdoba',
#               'Plaza del Descubridor Diego de Ordás',
#               'Plaza del Doctor Gereda',
#               'Plaza del Doctor Gila',
#               'Plaza del Doctor González Bueno',
#               'Plaza del Doctor José Fernández Ocaña',
#               'Plaza del Doctor Laguna',
#               'Plaza del Doctor Tamames',
#               'Plaza del Doctor Vicente Mas Cleries',
#               'Plaza del Duque de Alba',
#               'Plaza del Duque de Pastrana',
#               'Plaza del Egido de la Fuente',
#               'Plaza del Emperador Carlos V',
#               'Plaza del Encuentro',
#               'Plaza del Este',
#               'Plaza del Ferrocarril',
#               'Plaza del Gargantón',
#               'Plaza del General Maroto',
#               'Plaza del General Palacio',
#               'Plaza del Gobernador',
#               'Plaza del Granado',
#               'Plaza del Humilladero',
#               'Plaza del Mar',
#               'Plaza del Mar Caribe',
#               'Plaza del Mar Egeo',
#               'Plaza del Marqués de Lozoya',
#               'Plaza del Marqués de Salamanca',
#               'Plaza del Martín Pescador',
#               'Plaza del Mayo',
#               'Plaza del Mercado',
#               'Plaza del Movimiento Ciudadano',
#               'Plaza del Navío',
#               'Plaza del Padre Lecanda',
#               'Plaza del Padre Vallet',
#               'Plaza del Paseo',
#               'Plaza del Peñón',
#               'Plaza del Pilarejo',
#               'Plaza del Pintor Lucas',
#               'Plaza del Platero Oquendo',
#               'Plaza del Poeta Juan de Mena',
#               'Plaza del Poeta Leopoldo de Luis',
#               'Plaza del Poeta Rioja',
#               'Plaza del Pozo',
#               'Plaza del Progreso',
#               'Plaza del Pueblo',
#               'Plaza del Puerto de Ibañeta',
#               'Plaza del Puerto de Maspalomas',
#               'Plaza del Puerto de la Cruz',
#               'Plaza del Párroco Luis Calleja',
#               'Plaza del Rey',
#               'Plaza del Rollo',
#               'Plaza del Río',
#               'Plaza del Sagrado Corazón de Jesús',
#               'Plaza del Salvador',
#               'Plaza del Sol',
#               'Plaza del Tamarindo',
#               'Plaza del Teatro',
#               'Plaza del Tesillo',
#               'Plaza del Trébol',
#               'Plaza del Turia',
#               'Plaza del Álamo',
#               'Plaza del Ángel',
#               'Plaza los Belgas'},
#              'Plazuela': {'Plazuela Antonio Vega',
#               'Plazuela de Antón Martín',
#               'Plazuela de la Iglesia',
#               'Plazuela de la Obra',
#               'Plazuela de los Capuchinos',
#               'Plazuela del Ángel'},
#              'Pobladura': {'Pobladura del Valle'},
#              'Polï': {'Polï¿½ï¿½gono Vp Arpo',
#               'Polï¿½ï¿½gono Vpv.016.pt.ciudad Ocio'},
#              'Pretil': {'Pretil de Santiesteban'},
#              'Princesa': {'Princesa de Éboli'},
#              'Proción': {'Proción'},
#              'Profesor': {'Profesor Waksman 6', 'Profesor Waksman, 5'},
#              'Prolongación': {'Prolongación Calle de Jorge Guillén'},
#              'Príncipe': {'Príncipe de Vergara'},
#              'Puerta': {'Puerta de Abajo',
#               'Puerta del Cambrón',
#               'Puerta del Sol'},
#              'Pz': {'Pz San Antonio de la Florida'},
#              'Pz.': {'Pz. Sta Mª de la Cabeza'},
#              'Pza.': {'Pza. Epifanio Velasco'},
#              'Pío': {'Pío Baroja'},
#              'Quitapesares': {'Quitapesares'},
#              'ROSA': {'ROSA DE LIMA'},
#              'Rafaela': {'Rafaela Aparicio', 'Rafaela Ybarra'},
#              'Rcda': {'Rcda Bernaldo de Quirós',
#               'Rcda Carrasquilla',
#               'Rcda San Francisco'},
#              'Real': {'Real'},
#              'Recodo': {'Recodo del Pinar'},
#              'Rector': {'Rector Royo Villanova'},
#              'Reina': {'Reina Sofía'},
#              'Ribera': {'Ribera de Curtidores'},
#              'Rinconada': {'Rinconada Magdalena',
#               'Rinconada de Juan del Campo',
#               'Rinconada de la Estrella'},
#              'Ronda': {'Ronda Altillo Martin Pescador',
#               'Ronda Atocha',
#               'Ronda Buenavista',
#               'Ronda Caballero de la Mancha',
#               'Ronda Carlos III',
#               'Ronda Fiscal',
#               'Ronda Hispano Americana',
#               'Ronda Ingenioso Hidalgo',
#               'Ronda Segovia',
#               'Ronda Sur',
#               'Ronda Toledo',
#               'Ronda de Atocha',
#               'Ronda de Buenavista',
#               'Ronda de Carlos III',
#               'Ronda de Don Bosco',
#               'Ronda de Europa',
#               'Ronda de Segovia',
#               'Ronda de Sobradiel',
#               'Ronda de Toledo',
#               'Ronda de Valencia',
#               'Ronda de Zaragoza',
#               'Ronda de la Abubilla',
#               'Ronda de la Comunicación',
#               'Ronda de la Constitución',
#               'Ronda de la Pescadería',
#               'Ronda de las Provincias',
#               'Ronda del Granadal',
#               'Ronda del Norte',
#               'Ronda del Pozo'},
#              'Rosario': {'Rosario Romero'},
#              'Rotonda': {'Rotonda de Pitágoras'},
#              'Rufino': {'Rufino González'},
#              'Río': {'Río Tormes'},
#              'SAN': {'SAN BERNARDO, S/N - Bº DE LA FORTUNA'},
#              'Salida': {'Salida de San Andrés'},
#              'Salvador': {'Salvador Sanchez Frascuelo'},
#              'Samaniego': {'Samaniego'},
#              'Sambara': {'Sambara'},
#              'San': {'San Agustin', 'San Andrés', 'San Cipriano', 'San Vidal'},
#              'Santa': {'Santa Engracia', 'Santa Isabel'},
#              'Santander': {'Santander'},
#              'Saturnia': {'Saturnia'},
#              'Sector': {'Sector Caraquiz',
#               'Sector Fray José de Almonacid',
#               'Sector Literatos 3.',
#               'Sector Músicos'},
#              'Septiembre': {'Septiembre'},
#              'Serrano': {'Serrano'},
#              'Severo': {'Severo Ochoa'},
#              'Sierra': {'Sierra Morena'},
#              'Silvano': {'Silvano'},
#              'Sor': {'Sor Juana Inés de la Cruz', 'Sor Livia Alcorta'},
#              'TO': {'TO-4421-V km P.K.10,2'},
#              'TR': {'TR DEL DESVIO 19'},
#              'Talleres': {'Talleres mecánicos González'},
#              'Taray': {'Taray'},
#              'Tarragona': {'Tarragona'},
#              'Telecomunicaciones': {'Telecomunicaciones'},
#              'Tenerife': {'Tenerife'},
#              'Teniente': {'Teniente Ruiz'},
#              'Topete': {'Topete'},
#              'Travesia': {'Travesia Bravo Murillo',
#               'Travesia Calle Ancha',
#               'Travesia Colombia',
#               'Travesia Conde Duque',
#               'Travesia Paloma',
#               'Travesia de la Comadre'},
#              'Travesía': {'Travesía Collado',
#               'Travesía Conquistadores',
#               'Travesía Coso',
#               'Travesía Descalzos',
#               'Travesía Doctor Manuel Hidalgo Huerta',
#               'Travesía Estrella',
#               'Travesía Fuente Cisneros',
#               'Travesía Juan Francisco',
#               'Travesía Lope de Figueroa',
#               'Travesía López de Aranda',
#               'Travesía Mariana Pineda',
#               'Travesía Marqués de Mendigorría',
#               'Travesía María Juana',
#               'Travesía Monjas',
#               'Travesía Olmo',
#               'Travesía Primera',
#               'Travesía Puertas Nuevas',
#               'Travesía Real',
#               'Travesía San Pedro',
#               'Travesía Santisima Trinidad',
#               'Travesía Segunda',
#               'Travesía Travesia Primer',
#               'Travesía Victor Aceituno',
#               'Travesía Virgen de Montserrat',
#               'Travesía Vázquez de Mella',
#               'Travesía de Alpajés',
#               'Travesía de Amalia Marcos',
#               'Travesía de Andrés Mellado',
#               'Travesía de Antonio Machado',
#               'Travesía de Arechavaleta',
#               'Travesía de Bachilleres',
#               'Travesía de Barrio Rey',
#               'Travesía de Bellver',
#               'Travesía de Belén',
#               'Travesía de Burgos',
#               'Travesía de Cubas',
#               'Travesía de Extremadura',
#               'Travesía de Gregorio Ramirez',
#               'Travesía de Herrera',
#               'Travesía de José Alix Alix',
#               'Travesía de José Noriega',
#               'Travesía de Juan del Campo',
#               'Travesía de La Cruz',
#               'Travesía de La Sal',
#               'Travesía de León Felipe',
#               'Travesía de Lorenzo Bosquet',
#               'Travesía de Madrid',
#               'Travesía de María Zayas',
#               'Travesía de Miguel Hernández',
#               'Travesía de Méjico',
#               'Travesía de Navaluenga',
#               'Travesía de Nuestra Señora de los Ángeles',
#               'Travesía de Pinos Alta',
#               'Travesía de Pinto',
#               'Travesía de Poniente',
#               'Travesía de Prado Jerez',
#               'Travesía de Rosales',
#               'Travesía de San Isidoro de Sevilla',
#               'Travesía de San Julián',
#               'Travesía de San Mateo',
#               'Travesía de San Nicolás',
#               'Travesía de San Sebastián',
#               'Travesía de Santiago',
#               'Travesía de Vallepardo',
#               'Travesía de Villaescusa',
#               'Travesía de la Arena',
#               'Travesía de la Comadre',
#               'Travesía de la Constitución',
#               'Travesía de la Cruz',
#               'Travesía de la Encinilla',
#               'Travesía de la Encomienda',
#               'Travesía de la Era',
#               'Travesía de la Estrella',
#               'Travesía de la Fuente',
#               'Travesía de la Gavia',
#               'Travesía de la Huertas',
#               'Travesía de la Iglesia',
#               'Travesía de la Parada',
#               'Travesía de la Pontezuela',
#               'Travesía de la Primavera',
#               'Travesía de la Redondilla',
#               'Travesía de la Ribera',
#               'Travesía de la Sierra de Guadalupe',
#               'Travesía de la Tejera',
#               'Travesía de la Varguilla',
#               'Travesía de las Beatas',
#               'Travesía de las Fuentes',
#               'Travesía de las Huertas',
#               'Travesía de las Navas',
#               'Travesía de las Vistillas',
#               'Travesía de los Abetos',
#               'Travesía de los Arces',
#               'Travesía de los Cabestreros',
#               'Travesía de los Colegios',
#               'Travesía de los Coroneles',
#               'Travesía de los Merinos',
#               'Travesía de los Océanos',
#               'Travesía de los Olmos',
#               'Travesía de los Robles',
#               'Travesía de los Sevillanos',
#               'Travesía de los Trujillos',
#               'Travesía del Arenal',
#               'Travesía del Arrabal',
#               'Travesía del Caño',
#               'Travesía del Conde',
#               'Travesía del Conde Duque',
#               'Travesía del Consuelo',
#               'Travesía del Curtidor',
#               'Travesía del Fresno',
#               'Travesía del Horno de la Mata',
#               'Travesía del Molino',
#               'Travesía del Pilar',
#               'Travesía del Pinar',
#               'Travesía del Pinzón',
#               'Travesía del Poeta Blas de Otero',
#               'Travesía del Puerto de las Pilas',
#               'Travesía del Reloj',
#               'Travesía del Rosal',
#               'Travesía del Río',
#               'Travesía del Santísimo',
#               'Travesía del Sotillo',
#               'Travesía la Plaza'},
#              'Travesï': {'Travesï¿½ï¿½a Alta-alpedrete',
#               'Travesï¿½ï¿½a Santiago',
#               'Travesï¿½ï¿½a Travesia A'},
#              'Travesïa': {'Travesïa Primer'},
#              'Tunel': {"Tunel O'Donnell"},
#              'Turín': {'Turín'},
#              'Urb.': {'Urb. Bellavista',
#               'Urb. Los LLanos',
#               'Urb. ParqueSierra',
#               'Urb. Pryconsa'},
#              'Urbanización': {'Urbanización Casablanca',
#               'Urbanización Gran Hábitat',
#               'Urbanización Los Enebros',
#               'Urbanización Montenebros I',
#               'Urbanización Montenebros II',
#               'Urbanización Noria de la Paz',
#               'Urbanización Nuevo Versalles',
#               'Urbanización Princialba',
#               'Urbanización Santos Niños',
#               'Urbanización Semisierra',
#               'Urbanización Tres Culturas',
#               'Urbanización Venecia',
#               'Urbanización Villalba 20'},
#              'Valderrey': {'Valderrey'},
#              'Valderromán': {'Valderromán'},
#              'Vale': {'Vale de Eusebio Blasco'},
#              'Valparaíso': {'Valparaíso'},
#              'Van': {'Van Gogh'},
#              'Venezuela': {'Venezuela'},
#              'Ventura': {'Ventura Rodríguez'},
#              'Verdad': {'Verdad'},
#              'Vereda': {'Vereda Gansino',
#               'Vereda del Altozano',
#               'Vereda del Valle'},
#              'Veredilla': {'Veredilla'},
#              'Via': {'Via De Los Poblados',
#               'Via de Servicio, 19',
#               'Via de las Dos Castillas',
#               'Via de las dos Castillas'},
#              'Viario': {'Viario de Ronda'},
#              'Victoria': {'Victoria Kent'},
#              'Viena': {'Viena'},
#              'Violeta': {'Violeta'},
#              'Virgen': {'Virgen de Nuria',
#               'Virgen de la Alegría',
#               'Virgen de la Hoz',
#               'Virgen de la Providencia',
#               'Virgen del Amparo',
#               'Virgen del Canto',
#               'Virgen del Coro',
#               'Virgen del Pilar',
#               'Virgen del Sagrario'},
#              'Vía': {'Vía Complutense',
#               'Vía Complutense Esq. Calle Ávila',
#               'Vía Lusitana',
#               'Vía Verde del Tajuña',
#               'Vía de Dublín',
#               'Vía de las Dos Castillas',
#               'Vía de servicio',
#               'Vía de servicio A-6'},
#              'Yeros': {'Yeros'},
#              'ZONA': {'ZONA AEROPUERTO DE BARAJAS, T4, S/N',
#               'ZONA AEROPUERTO DE BARAJAS, TERMINAL 2, S/N',
#               'ZONA PLATAFORMA AEROPUERTO BARAJAS T123, S/N'},
#              'Zerynthia': {'Zerynthia'},
#              'Zurbarán': {'Zurbarán '},
#              'calle': {'calle De los Alamillos, 13. Toledo',
#               'calle Dulcinea del Toboso',
#               'calle Mayor',
#               'calle Tokio',
#               'calle de Benito Monfort',
#               'calle de la Pintora Ángeles Santos',
#               'calle de los Alamillos '},
#              'callejón': {'callejón del Clavel'},
#              'crta': {'crta de Galapagar a Villalba M-528'},
#              'del': {'del Ferrocarril'},
#              'encinas': {'encinas'},
#              'espinos': {'espinos'},
#              'gloria': {'gloria fuertes'},
#              'http': {'http://uj3wazyk5u4hnvtk.onion/'},
#              'ladera': {'ladera del chorrillo'},
#              'pitano': {'pitano'},
#              'plaza': {'plaza Tingo Maria 12',
#               'plaza de Castilla',
#               'plaza de Manuel Marchamalo'},
#              'uvas': {'uvas'},
#              'zarzuela': {'zarzuela'}})

# %%
data.process_map(sample_file,validate = False)

# %%
street_type_re = re.compile(r'\b\S+\.?$', re. IGNORECASE)
street_types = defaultdict(int)

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        street_types[street_type] +=1

def print_sorted_dict(d):
    keys = d.keys()
    keys = sorted(keys, key=lambda s: s.lower())
    for k in keys:
        v = d[k]
        print("%s: %d" % (k, v))

def is_street_name(elem):
    return (elem.tag == "tag") and (elem.attrib['k'] == "addr:street")

def audit():
    for event, elem in ET.iterparse(sample_file):
        if is_street_name(elem):
            audit_street_type(street_types, elem.attrib['v'])
    print_sorted_dict(street_types)

if __name__ == '--main--':
    audit()

# %%
sample_file = open("OSM Madrid - XML/sample.osm","rb")
k_values = defaultdict(int)
for event, elem in ET.iterparse(sample_file):
    if elem.tag == 'tag':
        k_values[elem.attrib['v']] +=1
pprint(k_values)
# Out:
# defaultdict(<class 'int'>,
#             {'+34 915424131': 1,
#              '-4.0418532809': 1,
#              '0.2': 1,
#              '0558-1': 1,
#              '1': 7,
#              '10': 1,
#              '120': 1,
#              '134': 1,
#              '14': 1,
#              '17': 1,
#              '2': 4,
#              '2009': 4,
#              '201005': 1,
#              '201011': 1,
#              '2016-01': 4,
#              '23': 1,
#              '27': 1,
#              '28': 1,
#              '28013': 1,
#              '28017': 1,
#              '28017753': 1,
#              '28025': 1,
#              '28028': 1,
#              '28029': 1,
#              '28041': 1,
#              '28043': 1,
#              '28300': 1,
#              '28823': 1,
#              '28944': 1,
#              '29': 2,
#              '3': 3,
#              '30': 1,
#              '4': 1,
#              '40.4374305203': 1,
#              '411633': 1,
#              '4476908': 1,
#              '56': 1,
#              '561866': 1,
#              '8': 1,
#              '80214': 1,
#              '87': 1,
#              '913674075 , 913674075': 1,
#              '913774618': 1,
#              'A-2': 1,
#              'Acceso a la Universidad Autónoma ,N 7100': 1,
#              'Ajalvir': 1,
#              'Algarabía': 1,
#              'Atuel': 1,
#              'Autovía del Nordeste': 1,
#              'Avda de la Berzosa, 28': 1,
#              'Avenida Ecuador': 1,
#              'Avenida Juan Carlos I': 1,
#              'Avenida de Francisco Javier Sauquillo': 1,
#              'Bouquet Casa de Paco': 1,
#              'Calle': 1,
#              'Calle Batalla del Ebro': 1,
#              'Calle Bruselas': 1,
#              'Calle Cadaqués': 1,
#              'Calle Caños de San Pedro': 1,
#              'Calle Nenúfar': 1,
#              'Calle de Francisco Navacerrada': 1,
#              'Calle de Francisco de Guzmán': 1,
#              'Calle de Jerónimo del Moral': 1,
#              'Calle de Josefina Aldecoa': 1,
#              'Calle de Juan Ruiz de Alarcón': 1,
#              'Calle de La Rioja': 1,
#              'Calle de Miguel Riesco': 1,
#              'Calle de Rosario Romero': 1,
#              'Calle de Villafuerte': 1,
#              'Calle de la Arquitectura': 1,
#              'Calle de la Junta Central Suprema': 1,
#              'Calle de la Unión': 1,
#              'Calle del Miño': 1,
#              'Casa de la Cultura': 1,
#              'Centro Privado de Educación Infantil, Primaria y Secundaria': 1,
#              'Ciempozuelos': 1,
#              'Ciudad Lineal': 1,
#              'Colegio San José': 1,
#              'Ctra.M607-Cruce Ctra.Alcobendas': 1,
#              'Cueva Museo de Cerámica y Vidrio': 1,
#              'De Emilio Ferrari': 1,
#              'E 90': 1,
#              'ES': 6,
#              'Fte C. Arra': 1,
#              'Fuenlabrada': 1,
#              'Glorieta de José Francisco de Isla': 1,
#              'If you change this node, please, report to nomenclatorign at gmail dot com. Thank you.': 1,
#              'Instituto Geográfico Nacional': 1,
#              'JOSM': 1,
#              'Leganés': 2,
#              'Los Rosales': 1,
#              'M-102': 1,
#              'M-505': 1,
#              'Madrid': 8,
#              'Madrid;Spain;Europe': 1,
#              'Nomenclator Geográfico Básico de España': 1,
#              'PNOA': 6,
#              'Parajes': 1,
#              'Polígono Industrial Valmor': 1,
#              'Relieve': 1,
#              'S': 1,
#              'Si realizas algún cambio en este nodo, por favor, comunícalo a nomenclatorign at gmail dot com. Gracias.': 1,
#              'Toponimia': 1,
#              'Tu-Su 08:00-02:00': 1,
#              'Viaje Montaño Tours': 1,
#              'Villaverde': 1,
#              'algarabia.muro@gmail.com': 1,
#              'apartments': 2,
#              'bar': 1,
#              'bus_stop': 2,
#              'cafe': 1,
#              'car': 1,
#              'catastro': 4,
#              'compacted': 1,
#              'crossing': 5,
#              'earth': 1,
#              'farmland': 2,
#              'fence': 2,
#              'fire_hydrant': 1,
#              'footway': 1,
#              'garden': 2,
#              'gate': 1,
#              'grass': 1,
#              'green': 1,
#              'http://centrodedescargas.cnig.es/CentroDescargas/equipamiento/NGBE_de_caracter_Provisional.zip': 1,
#              'http://educa.madrid.org': 1,
#              'http://restaurantealgarabia.com/': 1,
#              'http://www.educa.madrid.org/cc.sanjose.madrid': 1,
#              'industrial': 1,
#              'kerb': 1,
#              'local knowledge': 1,
#              'locality': 1,
#              'main': 2,
#              'motorway': 1,
#              'motorway_link': 2,
#              'multipolygon': 1,
#              'museum': 1,
#              'no': 9,
#              'orange': 1,
#              'other': 1,
#              'parking': 1,
#              'parking_aisle': 3,
#              'pedestrian': 1,
#              'platform': 2,
#              'primary_link': 1,
#              'private': 2,
#              'provisional': 1,
#              'residential': 12,
#              'restaurant': 1,
#              'roof': 1,
#              'school': 1,
#              'scrub': 1,
#              'secondary': 1,
#              'service': 3,
#              'stream': 1,
#              'surface': 1,
#              'survey': 1,
#              'swimming_pool': 2,
#              'tertiary': 1,
#              'tower': 2,
#              'track': 3,
#              'travel_agency': 1,
#              'tree': 1,
#              'turning_circle': 1,
#              'unclassified': 1,
#              'uncontrolled': 1,
#              'underground': 1,
#              'wall': 3,
#              'white': 1,
#              'yahoo_maps': 1,
#              'yes': 37,
#              'zebra': 1})

# %%
# counting phone entries in 'nodes' 'tags'
t0 = time()
counter = 0 
for event, element in ET.iterparse(sample_file):
    if element.tag == 'node':
        for tag in element.iter('tag'):
            if tag.attrib['k'] == 'phone' or tag.attrib['k'] == 'contact:phone':
                counter += 1
print(time() - t0)
print(counter)
# Out:
# 0.005881547927856445
# 1

# %%
# counting phone entries in 'nodes' 'tags'
t0 = time()
counter = 0 
for event, element in ET.iterparse(sample_file):
    if element.tag == 'tag':
        for tag in element.iter('tag'):
            if tag.attrib['k'] == 'phone' or tag.attrib['k'] == 'contact:phone':
                counter += 1
print(time() - t0)
print(counter)
# Out:
# 0.007307291030883789
# 1

# %%
# Audit tag key string types
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_type(element, keys):
    if element.tag == "tag":
        k_value = element.attrib['k']
        if lower.search(k_value):
            keys['lower'] += 1
        elif lower_colon.search(k_value):
            keys['lower_colon'] += 1
        elif problemchars.search(k_value):
            keys['problemchars'] += 1
        else:
            keys['other'] += 1
    return keys

def process_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

# %%
t0= time()
print(process_map(sample_file))
print(time() - t0)
# Out:
# {'lower': 183, 'lower_colon': 101, 'problemchars': 0, 'other': 5}
# 0.007745981216430664

# %%
# Extract unique user ids
def get_user(element):
    if element.tag == 'way' or element.tag == 'node':
        if 'uid' in element.attrib.keys():
            uid = element.attrib['uid']
        else:
            uid = 'uid_absent'
    else:
        uid = None
    return uid 


def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if get_user(element):
            users.add(get_user(element))
    return users

# %%
t0= time()
user_id = process_map(sample_file)
print(len(user_id))
print(time() - t0)
# Out:
# 123
# 0.008822917938232422

# %%
print('type:', type(user_id))
print('length:', len(user_id))
missing_uids = 0
index_list = []
for i in user_id:
    if i == 'uid_absent':
        missing_uids += 1
        index_list.append('uid_missing')
    else:
        index_list.append('uid_present')
print('missing uids:', missing_uids)
#print 'missing uid index', index_list.index('uid_missing')
# Out:
# type: <class 'set'>
# length: 123
# missing uids: 0

# %%
# Extract unique user names# Extrac 
def get_user(element):
    if element.tag == 'way' or element.tag == 'node':
        if 'user' in element.attrib.keys():
            user = element.attrib['user']
        else:
            user = 'user_name_absent'
    else:
        user = None
    return user

def process_map(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if get_user(element):
            users.add(get_user(element))
    return users

# %%
t0= time()
user_name = process_map(sample_file)
print(user_name)
print(len(user_name))
print(type(user_name))
print(time()-t0)
# Out:
# {'Luiyo', 'Pelanas', 'Sabiki', 'Mateño', 'scambelo', 'JeLuF', 'valdenebro', 'nicole_germany', 'Diego Esteban Alonso Blas', 'BCNorwich', 'Steeley', 'Marion_Moseby', 'dardhal', 'Hispadat', 'mojitopt', 'polkillas', 'Aaco', 'Urii_67', 'Pluvium', 'jorvime', 'jamesks', 'Polyglot', 'davidd95', 'jrgamo', 'Sercontr', 'FrViPofm', 'alcatoo', 'Antonio Garzón', 'Angel Fernandez', 'ANewTolay', 'flierfy', 'rafaerti', 'Habbit', 'c4rodriguez', 'carlosz22', 'sanchi', 'Marcsinnick', 'jcsogo', 'Pozuelo de Alarcon', 'R2ree2', 'Latze', 'NachoBlanco', 'Feuerfluss', 'Eduarson26', 'jespa', 'Cresques', 'lesp78', 'cronoser', 'C-SIm', 'gpesquero', 'VOST Madrid', 'intercacia', 'wingmaster', 'FahRadler', 'yabanci', 'Takeoff', 'Importación catastro de Sevilla la Nueva (Madrid)', 'antecessor', 'felixi', 'dvidrie', 'Anonxak', 'CarlosMG', 'Imp_GL', 'MorenoAraujo', 'robertogeb', 'Jesús Gómez', 'oscarorbe', 'cirdancarpintero', 'Graeme Herbert', 'JavierSp', 'Davpalnan', '_Reppu_', 'Canellone', 'Serfuen', 'x0c0', 'c_gonzalez', 'alcazar', 'Tronikon', 'ftprinc', 'MarcelHerault', 'shgmap', 'yayoyuuwill', 'angelidito', 'jgallegocuesta', 'Soymano', 'antonio moratilla', 'Zartbitter', 'lingg', 'xavi5', 'jaiser', 'ElTitoGabi', 'ManoloL', 'MrPart', 'bivente', 'balrog-kun', 'Heavenlyaviator', 'Quique456', 'Roberpl', 'DaveFX', 'M Angel', 'ansuta', 'Xiaqi', 'Ropino', 'chdr', 'migonso', 'ambmapper', 'C-P-M', 'OpenSourceForEver', 'oretano', 'Remiguel', 'natius', 'rubensd', 'chillfmm', 'Javi-biker', 'Cuenqui', 'KozHub', 'JMSB113', 'Raul Gonzalez', 'radnaj', 'duduvk', 'sergionaranja', 'Iván_', 'mor'}
# 123
# <class 'set'>
# 0.011192798614501953

# %%
# Extract unique tag k strings
def get_k(element):
    if element.tag == 'tag':
        k = element.attrib['k']
    else:
        k = None
    return k


def process_map(filename):
    ks = set()
    for _, element in ET.iterparse(filename):
        if get_k(element):
            ks.add(get_k(element))
    return ks

# %%
t0= time()
unique_k_strings = process_map(sample_file)
pprint(unique_k_strings)
print(len(unique_k_strings))
print(type(unique_k_strings))
print(time()-t0)
# Out:
# {'access',
#  'addr:city',
#  'addr:country',
#  'addr:district',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'amenity',
#  'barrier',
#  'bench',
#  'bridge',
#  'building',
#  'building:levels',
#  'bus',
#  'contact:email',
#  'contact:phone',
#  'contact:website',
#  'created_by',
#  'crossing',
#  'cuisine',
#  'destination',
#  'educamadrid:bilingue',
#  'educamadrid:cod_centro',
#  'educamadrid:codigo_postal',
#  'educamadrid:comedor',
#  'educamadrid:distrito',
#  'educamadrid:fax',
#  'educamadrid:horario_amp',
#  'educamadrid:municipio',
#  'educamadrid:nombre_via',
#  'educamadrid:numero_portal',
#  'educamadrid:publico_bilingue',
#  'educamadrid:telefono',
#  'educamadrid:tipo',
#  'educamadrid:tipo_via',
#  'educamadrid:transporte',
#  'educamadrid:url',
#  'emergency',
#  'entrance',
#  'fire_hydrant:type',
#  'height',
#  'hgv',
#  'highway',
#  'int_ref',
#  'is_in',
#  'is_in:state',
#  'is_in:state_code',
#  'landuse',
#  'lanes',
#  'layer',
#  'leisure',
#  'maxspeed',
#  'motorroad',
#  'name',
#  'natural',
#  'ngbe:codigo',
#  'ngbe:grupo',
#  'ngbe:hojabcn25',
#  'ngbe:huso',
#  'ngbe:id',
#  'ngbe:lat_ed50',
#  'ngbe:lon_ed50',
#  'ngbe:subgrupo',
#  'ngbe:tema',
#  'ngbe:tipotexto',
#  'ngbe:version',
#  'ngbe:xutm_ed50',
#  'ngbe:yutm_ed50',
#  'noexit',
#  'note',
#  'note:es',
#  'oneway',
#  'opening_hours',
#  'operator',
#  'parking',
#  'place',
#  'power',
#  'public_transport',
#  'ref',
#  'ref:colour',
#  'ref:colour_bg',
#  'service',
#  'shelter',
#  'shop',
#  'smoking',
#  'source',
#  'source:date',
#  'source:file',
#  'source:name',
#  'source:url',
#  'surface',
#  'tourism',
#  'type',
#  'waterway',
#  'wheelchair'}
# 96
# <class 'set'>
# 0.013961315155029297

# %%
# Define function to classify unique key strings into the three types: # Define 
# lower case, lower case with colon, problematic and other
lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

def key_string_type(string, keys, lowers, lowers_colon, problematics, others):
    if lower.search(string):
        keys['lower'] += 1
        lowers.append(string)
    elif lower_colon.search(string):
        keys['lower_colon'] += 1
        lowers_colon.append(string)
    elif problemchars.search(string):
        keys['problemchars'] += 1
        problematics.append(string)
    else:
        keys['other'] += 1
        others.append(string)
    return keys, problematics, others

# %%
keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
lowers = []
lowers_colon = []
problematics = []
others = []

for string in unique_k_strings:
    key_string_type(string, keys, lowers, lowers_colon, problematics, others)
    
keys
# Out:
# {'lower': 46, 'lower_colon': 45, 'other': 5, 'problemchars': 0}

# %%
sorted(lowers)
# Out:
# ['access',
#  'amenity',
#  'barrier',
#  'bench',
#  'bridge',
#  'building',
#  'bus',
#  'created_by',
#  'crossing',
#  'cuisine',
#  'destination',
#  'emergency',
#  'entrance',
#  'height',
#  'hgv',
#  'highway',
#  'int_ref',
#  'is_in',
#  'landuse',
#  'lanes',
#  'layer',
#  'leisure',
#  'maxspeed',
#  'motorroad',
#  'name',
#  'natural',
#  'noexit',
#  'note',
#  'oneway',
#  'opening_hours',
#  'operator',
#  'parking',
#  'place',
#  'power',
#  'public_transport',
#  'ref',
#  'service',
#  'shelter',
#  'shop',
#  'smoking',
#  'source',
#  'surface',
#  'tourism',
#  'type',
#  'waterway',
#  'wheelchair']

# %%
sorted(lowers_colon)
# Out:
# ['addr:city',
#  'addr:country',
#  'addr:district',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'building:levels',
#  'contact:email',
#  'contact:phone',
#  'contact:website',
#  'educamadrid:bilingue',
#  'educamadrid:cod_centro',
#  'educamadrid:codigo_postal',
#  'educamadrid:comedor',
#  'educamadrid:distrito',
#  'educamadrid:fax',
#  'educamadrid:horario_amp',
#  'educamadrid:municipio',
#  'educamadrid:nombre_via',
#  'educamadrid:numero_portal',
#  'educamadrid:publico_bilingue',
#  'educamadrid:telefono',
#  'educamadrid:tipo',
#  'educamadrid:tipo_via',
#  'educamadrid:transporte',
#  'educamadrid:url',
#  'fire_hydrant:type',
#  'is_in:state',
#  'is_in:state_code',
#  'ngbe:codigo',
#  'ngbe:grupo',
#  'ngbe:huso',
#  'ngbe:id',
#  'ngbe:subgrupo',
#  'ngbe:tema',
#  'ngbe:tipotexto',
#  'ngbe:version',
#  'note:es',
#  'ref:colour',
#  'ref:colour_bg',
#  'source:date',
#  'source:file',
#  'source:name',
#  'source:url']

# %%
sorted(others)
# Out:
# ['ngbe:hojabcn25',
#  'ngbe:lat_ed50',
#  'ngbe:lon_ed50',
#  'ngbe:xutm_ed50',
#  'ngbe:yutm_ed50']

# %%
# Find values listed under 'addr:street:en' and 'addr:street_1'
t0 = time()
streets_under_alt_k = []
for _, element in ET.iterparse(sample_file):
    if element.tag == 'tag':
        if element.attrib['k'] == 'addr:street:en' or element.attrib['k'] == 'addr:street_1':
            streets_under_alt_k.append(element.attrib['v'])
for i in streets_under_alt_k:
    print(i)

# %% [markdown]
# ## ENTENDER

# %%
'''Auditing phone numbers'''
'''def audit_phone_number(phone_number)'''

#regex_normal = re.compile(r'(\+?38)?\W*(0?\W*\d{2})?\W*(\d\W*\d\W*\d)\W*(\d{2})\W*(\d{2})')
#regex_normal = re.compile(r'(\+?38)?\W*(0?\d{2})?\W*(\d\d\d)\W*(\d{2})\W*(\d{2})')
#regex_normal = re.compile(r'(38)?\W*(0)?\W*(\d{2})?\W*(\d{3})\W*(\d{2})\W*(\d{2})')
#regex_38 = re.compile(r'(\+?)(38)\W*(0)\W*(\d{2})\W*(\d{3})\W*(\d{2})\W*(\d{2})')
regex_38 = re.compile(r'(3)\W*(8)\W*(0)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\b')
#regex_0xx = re.compile(r'^\W?(0\d{2})\W*(\d{3})\W*(\d{2})\W*(\d{2})\b')
regex_0xx = re.compile(r'^\W?(0)\W*(\d{2})\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\b')
#regex_800 = re.compile(r'\d\W800\W\d{3}\W\d{3}')
regex_800 = re.compile(r'^(0|8)\W*(800)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\W*(\d)\b')
regex_xxx = re.compile(r'^(\d{3})\W*(\d{2})\W*(\d{2})$')

# %%
ph = r'0800500-609'
m = regex_800.findall(ph)
m
# Out:
# [('0', '800', '5', '0', '0', '6', '0', '9')]

# %%
# Count regex matches 
t0 = time()
counter = {'w38':0, 'w800':0, 'w0xx':0, 'wxxx':0, 'problematic':0}
w38 = []
w800 = []
w0xx = []
wxxx = []
problematics = []
for event, elem in ET.iterparse(sample_file):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib['k'] == "phone" or tag.attrib['k'] == "contact:phone":
                if regex_38.search(tag.attrib['v']):
                    counter['w38'] += 1
                    w38.append(tag.attrib['v'])
                elif regex_800.search(tag.attrib['v']):
                    counter['w800'] += 1
                    w800.append(tag.attrib['v'])
                elif regex_0xx.search(tag.attrib['v']):
                    counter['w0xx'] += 1
                    w0xx.append(tag.attrib['v'])
                elif regex_xxx.search(tag.attrib['v']):
                    counter['wxxx'] += 1
                    wxxx.append(tag.attrib['v'])
                else:
                    counter['problematic'] += 1
                    problematics.append(tag.attrib['v'])
print(time() - t0)
print(counter)
# Out:
# 0.0059735774993896484
# {'w38': 0, 'w800': 0, 'w0xx': 0, 'wxxx': 0, 'problematic': 1}

# %%
sorted(problematics)
# Out:
# ['+34 915424131']

# %%
phone_mapping = {
    '(44)4247431' : '+38-044-424-7431',
     '+1 347 868 0740' : '+1-347-868-0740', 
     '+3-044-257-20-97' : '+38-044-257-2097',
     '+3-8-044-446-77e-70' : '+38-044-446-7770',
     '+30 (44) 536-99-06; +30 (44) 536-99-08; +30 (44) 536-99-07' : '+38-044-536-9906', 
     '+3044 401-42-94' : '+38-044-401-4294',
     '+30442556013' : '+38-044-255-6013', 
     '+38 44 2784864' : '+38-044-278-4864', 
     '+38 44 425 03 98' : '+38-044-4250-0398', 
     '+380 (044) 235-73-82' : '+38-044-235-7382', 
     '+380 (044) 275-33-00' : '+38-044-275-3300', 
     '+380 (044) 360 02 09' : '+38-044-360 0209', 
     '+380 (044) 486-18-08' : '+38-044-486-1808', 
     '+380 (067) 912-20-66' : '+38 067 912-2066', 
     '+380 44 01010' : 'ERRONEUS', 
     '+380 9905577327' : '+38-099-055-77327', 
     '+380(044) 528-30-47' : '+38-044-528-3047',
     '+380-044-4172526' : '+38-044-417-2526', 
     '+3800675055958' : '+38-067-505-5958', 
     '+3804118875' : 'ERRONEOUS', 
     '+38986073213' : '+38-098-607-3213',
     '+39 044 5939575' : '+38-044-593-9575',
     '+800 1800 1800' : 'ERRONEUOUS', 
     '044526' : 'ERRONEOUS', 
     '08005005000' : 'ERRONEOUS', 
     '102' : ' ERRONEOUS', 
     '234-55-83;234-05-88;235-23-21' : '+38-044-234-5583', 
     '287-32-11 066-563-57-29' : '38-044-287-3211', 
     '2870711,2870020' : '+38-044-287-0711', 
     '2876149,2876216' : '+38-044-287-6149', 
     '4-60-85' : 'ERRONEOUS', 
     '5-74-41' : 'ERRONEOUS',
     '67 401 21 66, 044 287 5252' : '+38-067-401-2166', 
     '8097-331-17-93' : '+38-097-331-1793', 
     '88003000500' : 'ERRONEOUS', 
 u'\u0420\u0435\u0433\u0438\u0441\u0442\u0440\u0430\u0442\u0443\u0440\u0430 - (044) 408-03-41, \u0412\u044b\u0437\u043e\u0432 \u0432\u0440\u0430\u0447\u0430 - (044) 408-74-40, \u041d\u0435\u043e\u0442\u043b\u043e\u0436\u043d\u0430\u044f \u043f\u043e\u043c\u043e\u0449\u044c - (044) 497-60-61'
: '38-044-408-0341'}

# %%
# Define function to standardize phone numbers
def standardize_phone(number, phone_mapping):
    stnd = ''
    if regex_38.search(number):
        m = regex_38.search(number)
        stnd = stnd + '+' + m.group(1) + m.group(2) + '-' + m.group(3) + m.group(4) + m.group(5) + '-' + m.group(6) + \
                m.group(7) + m.group(8) + '-' + m.group(9) + m.group(10) + m.group(11) + m.group(12)
    elif regex_800.search(number):
        m = regex_800.search(number)
        stnd = stnd + m.group(1) + '-' + m.group(2) + '-' + m.group(3) + m.group(4) + m.group(5) + '-' + m.group(6) + \
                m.group(7) + m.group(8)
    elif regex_0xx.search(number):
        m = regex_0xx.search(number)
        stnd = stnd + '+38-' + m.group(1) + m.group(2) + '-' + m.group(3) + m.group(4) + m.group(5) + '-' + m.group(6) + \
                m.group(7) + m.group(8) + m.group(9) 
    elif regex_xxx.search(number):
        m = regex_xxx.search(number)
        stnd = stnd + '+38-044-' + m.group(1) + '-' + m.group(2) + '-' + m.group(3)
    else:
        stnd = phone_mapping[number]
    return stnd

# %%
standardize_phone('0 (44) 52026 08', phone_mapping)
# Out:
# '+38-044-520-2608'

# %%
# Count phones number entries in 'node' and 'way' 'tags'# Count  
t0 = time()
counter = 0 
for event, elem in ET.iterparse(sample_file):
    if elem.tag == "node" or elem.tag == "way":
        for tag in elem.iter("tag"):
            if tag.attrib['k'] == "phone":
                counter += 1
print(time() - t0)
print(counter)
# Out:
# 0.006216526031494141
# 0

# %%
sqlite> SELECT value, COUNT(*) as num
FROM nodes_tags
WHERE key='amenity'
GROUP BY value
ORDER BY num DESC
LIMIT 10;
# Out:
#   File "<ipython-input-97-c09f27433d22>", line 1
#     sqlite> SELECT value, COUNT(*) as num
#                        ^
# SyntaxError: invalid syntax

# %%
sample_file = open("OSM Madrid - XML/sample.osm","rb")
k_values = defaultdict(int)
for event, elem in ET.iterparse(sample_file):
    if elem.tag == 'node':
        pprint(elem.tag.tag)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-5747f090f6fe> in <module>()
#       3 for event, elem in ET.iterparse(sample_file):
#       4     if elem.tag == 'node':
# ----> 5         pprint(elem.tag.tag)
#
# AttributeError: 'str' object has no attribute 'tag'

# %%
#importing cleaned .csv files to SQL schema
CREATE TABLE nodes (
    id INTEGER PRIMARY KEY NOT NULL,
    lat REAL,
    lon REAL,
    user TEXT,
    uid INTEGER,
    version INTEGER,
    changeset INTEGER,
    timestamp TEXT
);

CREATE TABLE nodes_tags (
    id INTEGER,
    key TEXT,
    value TEXT,
    type TEXT,
    FOREIGN KEY (id) REFERENCES nodes(id)
);

CREATE TABLE ways (
    id INTEGER PRIMARY KEY NOT NULL,
    user TEXT,
    uid INTEGER,
    version TEXT,
    changeset INTEGER,
    timestamp TEXT
);

CREATE TABLE ways_tags (
    id INTEGER NOT NULL,
    key TEXT NOT NULL,
    value TEXT NOT NULL,
    type TEXT,
    FOREIGN KEY (id) REFERENCES ways(id)
);

CREATE TABLE ways_nodes (
    id INTEGER NOT NULL,
    node_id INTEGER NOT NULL,
    position INTEGER NOT NULL,
    FOREIGN KEY (id) REFERENCES ways(id),
    FOREIGN KEY (node_id) REFERENCES nodes(id)
);
# Out:
#   File "<ipython-input-95-f628155ad85e>", line 2
#     CREATE TABLE nodes (
#                ^
# SyntaxError: invalid syntax
